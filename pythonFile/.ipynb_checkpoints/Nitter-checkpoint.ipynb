# %% [markdown]
# # Brute force - Code pour plusieurs jours (MAJ suite à sécurité Nitter)

# %%
#pip install selenium
#pip install webdriver_manager
#pip install bs4

# %%
import datetime
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen, Request
import urllib.parse

# %%
# Créer une liste pour stocker les résultats de chaque jour
results = []

# %%
# Définir la date de début et la date de fin
start_date = datetime.date(2023, 1, 1)
end_date = datetime.date(2023, 6, 1)

# %%
# Chargement du dictionnaire des mots
dict_mot = pd.read_csv('PPD_Dictionnaire_des_mots.csv',sep=';')
print(dict_mot.to_string())
# Out:
#                           Mot  Fréquence
# 0       transition écologique        339
# 1                  production        128
# 2                     métiers        101
# 3                 compétences         96
# 4                    stockage         89
# 5                      enjeux         75
# 6                      impact         75
# 7          matières premières         74
# 8                 entreprises         71
# 9                 énergétique         59
# 10                    énergie         55
# 11                    chaleur         55
# 12                       plan         51
# 13                  industrie         45
# 14      développement durable         43
# 15                   capacité         42
# 16                  véhicules         42
# 17                     master         41
# 18                  batteries         40
# 19                     energy         37
# 20               consommation         36
# 21                        for         34
# 22                        all         34
# 23                sustainable         34
# 24                      earth         34
# 25                    déchets         33
# 26                  émissions         33
# 27                   fossiles         31
# 28                    interne         29
# 29                  matériaux         29
# 30               combustibles         29
# 31                    process         28
# 32                   branches         27
# 33                 estimation         27
# 34                   répondre         26
# 35                    actions         26
# 36                      table         26
# 37                     modèle         25
# 38                 entreprise         25
# 39                      total         24
# 40                     figure         24
# 41                 ressources         24
# 42                  formation         24
# 43                    réduire         23
# 44                    solaire         23
# 45                        twh         23
# 46                      enjeu         23
# 47                   énergies         23
# 48                  périmètre         22
# 49                 formations         22
# 50                     pompes         21
# 51                  effectifs         21
# 52                    sources         21
# 53                    facteur         21
# 54                    besoins         21
# 55                   ensemble         20
# 56                   mondiale         20
# 57                    impacts         20
# 58                        ges         20
# 59                 techniques         20
# 60                    qualité         20
# 61                        eau         20
# 62                   produits         20
# 63                    gestion         20
# 64                     requis         19
# 65                   associés         19
# 66              développement         19
# 67                       base         19
# 68                 électrique         18
# 69                      états         18
# 70              environnement         18
# 71                     charge         18
# 72                     flotte         18
# 73                 hypothèses         18
# 74                    analyse         18
# 75                      haute         17
# 76                température         17
# 77                     niveau         17
# 78                  raffinage         17
# 79                   éolienne         17
# 80                         tw         17
# 81             certifications         17
# 82                       coût         17
# 83                      élevé         17
# 84                  réduction         16
# 85                   analyses         16
# 86                     usines         16
# 87                   économie         16
# 88                  thermique         15
# 89                    famille         15
# 90                   solaires         15
# 91                     réseau         15
# 92                utilisation         15
# 93                     faible         15
# 94           macrocompétences         15
# 95                   procédés         15
# 96                  maîtriser         15
# 97                     nickel         14
# 98                      tesla         14
# 99               transmission         14
# 100                      opco         14
# 101              technologies         14
# 102                     capex         14
# 103              biodiversité         14
# 104                  réponses         14
# 105              utilisations         13
# 106                nécessaire         13
# 107                   carbone         13
# 108                logistique         13
# 109                 transport         13
# 110                  activité         13
# 111                   horaire         13
# 112               équipements         13
# 113             renouvelables         13
# 114                    achats         13
# 115                 chauffage         13
# 116                 recyclage         13
# 117                 résultats         13
# 118                       loi         13
# 119               fabrication         13
# 120                  graphite         13
# 121                      sols         13
# 122                 effluents         13
# 123            supplémentaire         13
# 124               difficultés         13
# 125               électriques         12
# 126                 éoliennes         12
# 127                   risques         12
# 128           environnemental         12
# 129               industriels         12
# 130                    france         12
# 131                industriel         12
# 132                 processus         12
# 133                   branche         12
# 134                 également         12
# 135                        gw         12
# 136                   secteur         12
# 137                 objectifs         12
# 138        entreprises vertes         12
# 139              optimisation         12
# 140                 renforcer         11
# 141                  salariés         11
# 142     transition ecologique        999
# 143    transition énergétique        999
# 144    transition energetique        999
# 145        énergies nouvelles        999
# 146        nouvelles énergies        999
# 147    énergies renouvelables        999
# 148        matieres premieres        999
# 149     enjeu environnemental        999
# 150   enjeux environnementaux        999
# 151                    efioul        999
# 152                   e-fioul        999
# 153     carburant de synthese        999
# 154     carburant de synthèse        999
# 155              biocarburant        999
# 156             bio-carburant        999
# 157  rechauffement climatique        999
# 158        voiture électrique        999
# 159      voitures électriques        999
# 160       véhicule électrique        999
# 161     véhicules électriques        999
# 162           pompe à chaleur        999
# 163     isolation du logement        999
# 164                   biochar        999
# 165           éolienne en mer        999
# 166          éoliennes en mer        999
# 167         éolienne offshore        999
# 168        éoliennes offshore        999
# 169                 hydrogène        999
# 170  consommation énergétique        999
# 171      sobriété énergétique        999

# %%
# Filtre manuel pour récupérer que les mots sur lesquels on peut scrapper
mots_a_conserver = [
    'transition écologique',
    'transition ecologique',
    'transition énergétique',
    'transition energetique',
    'énergies nouvelles',
    'nouvelles énergies',
    'énergies renouvelables'
    'matières premières',
    'matieres premieres',
    'enjeu environnemental',
    'enjeux environnementaux',
    'développement durable',
    'efioul',
    'e-fioul',
    'carburant de synthese',
    'carburant de synthèse',
    'biocarburant',
    'bio-carburant',
    'rechauffement climatique',
    'rechauffement climatique',
    'voiture électrique',
    'voitures électriques',
    'véhicule électrique',
    'véhicules électriques',
    'pompe à chaleur',
    'isolation du logement',
    'biochar',
    'éolienne en mer',
    'éoliennes en mer',
    'éolienne offshore',
    'éoliennes offshore',
    'hydrogène',
    'consommation énergétique',
    'sobriété énergétique',
    'entreprises vertes'
]

# Filtrer le dictionnaire de mots en ne conservant que les mots spécifiques
dict_mot_final = dict_mot[dict_mot['Mot'].isin(mots_a_conserver)]
dict_mot_final = dict_mot_final.reset_index(drop=True)
dict_mot_final
# Out:
#                          Mot  Fréquence
# 0      transition écologique        339
# 1      développement durable         43
# 2         entreprises vertes         12
# 3      transition ecologique        999
# 4     transition énergétique        999
# 5     transition energetique        999
# 6         énergies nouvelles        999
# 7         nouvelles énergies        999
# 8         matieres premieres        999
# 9      enjeu environnemental        999
# 10   enjeux environnementaux        999
# 11                    efioul        999
# 12                   e-fioul        999
# 13     carburant de synthese        999
# 14     carburant de synthèse        999
# 15              biocarburant        999
# 16             bio-carburant        999
# 17  rechauffement climatique        999
# 18        voiture électrique        999
# 19      voitures électriques        999
# 20       véhicule électrique        999
# 21     véhicules électriques        999
# 22           pompe à chaleur        999
# 23     isolation du logement        999
# 24                   biochar        999
# 25           éolienne en mer        999
# 26          éoliennes en mer        999
# 27         éolienne offshore        999
# 28        éoliennes offshore        999
# 29                 hydrogène        999
# 30  consommation énergétique        999
# 31      sobriété énergétique        999

# %%
# Construire la liste des mots à rechercher
mots_a_rechercher = dict_mot_final['Mot'].tolist()

# Remplacement des ' 'par '+' pour prératation à la requête 
mots_a_rechercher = [mots.replace(' ', '+') for mots in mots_a_rechercher]
mots_a_rechercher
# Out:
# ['transition+écologique',
#  'développement+durable',
#  'entreprises+vertes',
#  'transition+ecologique',
#  'transition+énergétique',
#  'transition+energetique',
#  'énergies+nouvelles',
#  'nouvelles+énergies',
#  'matieres+premieres',
#  'enjeu+environnemental',
#  'enjeux+environnementaux',
#  'efioul',
#  'e-fioul',
#  'carburant+de+synthese',
#  'carburant+de+synthèse',
#  'biocarburant',
#  'bio-carburant',
#  'rechauffement+climatique',
#  'voiture+électrique',
#  'voitures+électriques',
#  'véhicule+électrique',
#  'véhicules+électriques',
#  'pompe+à+chaleur',
#  'isolation+du+logement',
#  'biochar',
#  'éolienne+en+mer',
#  'éoliennes+en+mer',
#  'éolienne+offshore',
#  'éoliennes+offshore',
#  'hydrogène',
#  'consommation+énergétique',
#  'sobriété+énergétique']

# %%
# Boucle sur chaque mot à rechercher
for mot in mots_a_rechercher:
    # Réinitialiser la date de début pour chaque nouveau mot
    start_date_mot = start_date
    
    # Boucle sur chaque jour
    while start_date_mot <= end_date:
        since_date_mot = start_date_mot.strftime("%Y-%m-%d")
        until_date_mot = (start_date_mot + datetime.timedelta(days=1)).strftime("%Y-%m-%d")
        
        # Construire l'URL de la requête avec le mot et les dates du jour en cours
        query = urllib.parse.quote(mot)
        url = f"https://nitter.net/search?f=tweets&q={query}&since={since_date_mot}&until={until_date_mot}&near="
        print(url)

        # Requête HTTP & récupération du contenu de la page (+ ajout d'un header pour contourner la sécurité Nitter)
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
        req = Request(url, headers=headers)
        response = urlopen(req)
        soup = BeautifulSoup(response.read(), 'html.parser')

        # extraire les informations de chaque tweet pour le jour en cours
        tweet_contents = []
        tweet_dates = []
        tweet_links = []
        tweet_names = []
        tweet_names_id = []
        comment_stats = []
        retweet_stats = []
        quote_stats = []
        heart_stats = []

        for tweet in soup.find_all('div', {'class': 'timeline-item'}):
            # contenu du tweet
            content = tweet.find('div', {'class': 'tweet-content'}).text.strip()
            tweet_contents.append(content)

            # date du tweet
            date = tweet.find('span', {'class': 'tweet-date'}).a['title']
            tweet_dates.append(date)

            # lien du tweet
            link = tweet.find('a', {'class': 'tweet-link'})['href']
            tweet_links.append(link)

            # nom (title) du tweet
            name = tweet.find('a', {'class': 'fullname'})['title']
            tweet_names.append(name)

            # nom (id) du tweet
            name_id = tweet.find('a', {'class': 'username'})['title']
            tweet_names_id.append(name_id)

            # statistiques
            stats = tweet.find_all('div', {'class': 'icon-container'})
            comment_stats.append(stats[0].text.strip())
            retweet_stats.append(stats[1].text.strip())
            quote_stats.append(stats[2].text.strip())
            heart_stats.append(stats[3].text.strip())

        # ajouter les informations du jour en cours à la liste de résultats
        result = pd.DataFrame({
            'Content': tweet_contents,
            'Date': tweet_dates,
            'Link': tweet_links,
            'Utilisateur': tweet_names,
            'Utilisateur_id': tweet_names_id,
            'Comments': comment_stats,
            'Retweets': retweet_stats,
            'Quotes': quote_stats,
            'Hearts': heart_stats
        })
        results.append(result)

        # Passer à la prochaine date
        start_date_mot += datetime.timedelta(days=1)
# Out:
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-01&until=2023-01-02&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-02&until=2023-01-03&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-03&until=2023-01-04&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-04&until=2023-01-05&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-05&until=2023-01-06&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-06&until=2023-01-07&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-07&until=2023-01-08&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-08&until=2023-01-09&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-09&until=2023-01-10&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-10&until=2023-01-11&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-11&until=2023-01-12&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-12&until=2023-01-13&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-13&until=2023-01-14&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-14&until=2023-01-15&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-15&until=2023-01-16&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-16&until=2023-01-17&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-17&until=2023-01-18&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-18&until=2023-01-19&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-19&until=2023-01-20&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-20&until=2023-01-21&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-21&until=2023-01-22&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-22&until=2023-01-23&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-23&until=2023-01-24&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-24&until=2023-01-25&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-25&until=2023-01-26&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-26&until=2023-01-27&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-27&until=2023-01-28&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-28&until=2023-01-29&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-29&until=2023-01-30&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-30&until=2023-01-31&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-01-31&until=2023-02-01&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-01&until=2023-02-02&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-02&until=2023-02-03&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-03&until=2023-02-04&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-04&until=2023-02-05&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-05&until=2023-02-06&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-06&until=2023-02-07&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-07&until=2023-02-08&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-08&until=2023-02-09&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-09&until=2023-02-10&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-10&until=2023-02-11&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-11&until=2023-02-12&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-12&until=2023-02-13&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-13&until=2023-02-14&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-14&until=2023-02-15&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-15&until=2023-02-16&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-16&until=2023-02-17&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-17&until=2023-02-18&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-18&until=2023-02-19&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-19&until=2023-02-20&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-20&until=2023-02-21&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-21&until=2023-02-22&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-22&until=2023-02-23&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-23&until=2023-02-24&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-24&until=2023-02-25&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-25&until=2023-02-26&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-26&until=2023-02-27&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-27&until=2023-02-28&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-02-28&until=2023-03-01&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-01&until=2023-03-02&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-02&until=2023-03-03&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-03&until=2023-03-04&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-04&until=2023-03-05&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-05&until=2023-03-06&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-06&until=2023-03-07&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-07&until=2023-03-08&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-08&until=2023-03-09&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-09&until=2023-03-10&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-10&until=2023-03-11&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-11&until=2023-03-12&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-12&until=2023-03-13&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-13&until=2023-03-14&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-14&until=2023-03-15&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-15&until=2023-03-16&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-16&until=2023-03-17&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-17&until=2023-03-18&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-18&until=2023-03-19&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-19&until=2023-03-20&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-20&until=2023-03-21&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-21&until=2023-03-22&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-22&until=2023-03-23&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-23&until=2023-03-24&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-24&until=2023-03-25&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-25&until=2023-03-26&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-26&until=2023-03-27&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-27&until=2023-03-28&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-28&until=2023-03-29&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-29&until=2023-03-30&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-30&until=2023-03-31&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-03-31&until=2023-04-01&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-01&until=2023-04-02&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-02&until=2023-04-03&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-03&until=2023-04-04&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-04&until=2023-04-05&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-05&until=2023-04-06&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-06&until=2023-04-07&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-07&until=2023-04-08&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-08&until=2023-04-09&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-09&until=2023-04-10&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-10&until=2023-04-11&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-11&until=2023-04-12&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-12&until=2023-04-13&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-13&until=2023-04-14&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-14&until=2023-04-15&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-15&until=2023-04-16&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-16&until=2023-04-17&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-17&until=2023-04-18&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-18&until=2023-04-19&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-19&until=2023-04-20&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-20&until=2023-04-21&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-21&until=2023-04-22&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-22&until=2023-04-23&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-23&until=2023-04-24&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-24&until=2023-04-25&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-25&until=2023-04-26&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-26&until=2023-04-27&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-27&until=2023-04-28&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-28&until=2023-04-29&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-29&until=2023-04-30&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-04-30&until=2023-05-01&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-01&until=2023-05-02&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-02&until=2023-05-03&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-03&until=2023-05-04&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-04&until=2023-05-05&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-05&until=2023-05-06&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-06&until=2023-05-07&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-07&until=2023-05-08&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-08&until=2023-05-09&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-09&until=2023-05-10&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-10&until=2023-05-11&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-11&until=2023-05-12&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-12&until=2023-05-13&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-13&until=2023-05-14&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-14&until=2023-05-15&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-15&until=2023-05-16&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-16&until=2023-05-17&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-17&until=2023-05-18&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-18&until=2023-05-19&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-19&until=2023-05-20&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-20&until=2023-05-21&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-21&until=2023-05-22&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-22&until=2023-05-23&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-23&until=2023-05-24&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-24&until=2023-05-25&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-25&until=2023-05-26&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-26&until=2023-05-27&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-27&until=2023-05-28&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-28&until=2023-05-29&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-29&until=2023-05-30&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-30&until=2023-05-31&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-05-31&until=2023-06-01&near=
# https://nitter.net/search?f=tweets&q=transition%2B%C3%A9cologique&since=2023-06-01&until=2023-06-02&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-01&until=2023-01-02&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-02&until=2023-01-03&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-03&until=2023-01-04&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-04&until=2023-01-05&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-05&until=2023-01-06&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-06&until=2023-01-07&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-07&until=2023-01-08&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-08&until=2023-01-09&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-09&until=2023-01-10&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-10&until=2023-01-11&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-11&until=2023-01-12&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-12&until=2023-01-13&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-13&until=2023-01-14&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-14&until=2023-01-15&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-15&until=2023-01-16&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-16&until=2023-01-17&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-17&until=2023-01-18&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-18&until=2023-01-19&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-19&until=2023-01-20&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-20&until=2023-01-21&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-21&until=2023-01-22&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-22&until=2023-01-23&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-23&until=2023-01-24&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-24&until=2023-01-25&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-25&until=2023-01-26&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-26&until=2023-01-27&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-27&until=2023-01-28&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-28&until=2023-01-29&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-29&until=2023-01-30&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-30&until=2023-01-31&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-01-31&until=2023-02-01&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-01&until=2023-02-02&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-02&until=2023-02-03&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-03&until=2023-02-04&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-04&until=2023-02-05&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-05&until=2023-02-06&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-06&until=2023-02-07&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-07&until=2023-02-08&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-08&until=2023-02-09&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-09&until=2023-02-10&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-10&until=2023-02-11&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-11&until=2023-02-12&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-12&until=2023-02-13&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-13&until=2023-02-14&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-14&until=2023-02-15&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-15&until=2023-02-16&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-16&until=2023-02-17&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-17&until=2023-02-18&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-18&until=2023-02-19&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-19&until=2023-02-20&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-20&until=2023-02-21&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-21&until=2023-02-22&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-22&until=2023-02-23&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-23&until=2023-02-24&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-24&until=2023-02-25&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-25&until=2023-02-26&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-26&until=2023-02-27&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-27&until=2023-02-28&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-02-28&until=2023-03-01&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-01&until=2023-03-02&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-02&until=2023-03-03&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-03&until=2023-03-04&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-04&until=2023-03-05&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-05&until=2023-03-06&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-06&until=2023-03-07&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-07&until=2023-03-08&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-08&until=2023-03-09&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-09&until=2023-03-10&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-10&until=2023-03-11&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-11&until=2023-03-12&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-12&until=2023-03-13&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-13&until=2023-03-14&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-14&until=2023-03-15&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-15&until=2023-03-16&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-16&until=2023-03-17&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-17&until=2023-03-18&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-18&until=2023-03-19&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-19&until=2023-03-20&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-20&until=2023-03-21&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-21&until=2023-03-22&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-22&until=2023-03-23&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-23&until=2023-03-24&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-24&until=2023-03-25&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-25&until=2023-03-26&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-26&until=2023-03-27&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-27&until=2023-03-28&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-28&until=2023-03-29&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-29&until=2023-03-30&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-30&until=2023-03-31&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-03-31&until=2023-04-01&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-01&until=2023-04-02&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-02&until=2023-04-03&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-03&until=2023-04-04&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-04&until=2023-04-05&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-05&until=2023-04-06&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-06&until=2023-04-07&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-07&until=2023-04-08&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-08&until=2023-04-09&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-09&until=2023-04-10&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-10&until=2023-04-11&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-11&until=2023-04-12&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-12&until=2023-04-13&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-13&until=2023-04-14&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-14&until=2023-04-15&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-15&until=2023-04-16&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-16&until=2023-04-17&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-17&until=2023-04-18&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-18&until=2023-04-19&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-19&until=2023-04-20&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-20&until=2023-04-21&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-21&until=2023-04-22&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-22&until=2023-04-23&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-23&until=2023-04-24&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-24&until=2023-04-25&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-25&until=2023-04-26&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-26&until=2023-04-27&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-27&until=2023-04-28&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-28&until=2023-04-29&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-29&until=2023-04-30&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-04-30&until=2023-05-01&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-01&until=2023-05-02&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-02&until=2023-05-03&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-03&until=2023-05-04&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-04&until=2023-05-05&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-05&until=2023-05-06&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-06&until=2023-05-07&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-07&until=2023-05-08&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-08&until=2023-05-09&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-09&until=2023-05-10&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-10&until=2023-05-11&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-11&until=2023-05-12&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-12&until=2023-05-13&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-13&until=2023-05-14&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-14&until=2023-05-15&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-15&until=2023-05-16&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-16&until=2023-05-17&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-17&until=2023-05-18&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-18&until=2023-05-19&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-19&until=2023-05-20&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-20&until=2023-05-21&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-21&until=2023-05-22&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-22&until=2023-05-23&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-23&until=2023-05-24&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-24&until=2023-05-25&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-25&until=2023-05-26&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-26&until=2023-05-27&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-27&until=2023-05-28&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-28&until=2023-05-29&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-29&until=2023-05-30&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-30&until=2023-05-31&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-05-31&until=2023-06-01&near=
# https://nitter.net/search?f=tweets&q=d%C3%A9veloppement%2Bdurable&since=2023-06-01&until=2023-06-02&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-01&until=2023-01-02&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-02&until=2023-01-03&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-03&until=2023-01-04&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-04&until=2023-01-05&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-05&until=2023-01-06&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-06&until=2023-01-07&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-07&until=2023-01-08&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-08&until=2023-01-09&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-09&until=2023-01-10&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-10&until=2023-01-11&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-11&until=2023-01-12&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-12&until=2023-01-13&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-13&until=2023-01-14&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-14&until=2023-01-15&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-15&until=2023-01-16&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-16&until=2023-01-17&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-17&until=2023-01-18&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-18&until=2023-01-19&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-19&until=2023-01-20&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-20&until=2023-01-21&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-21&until=2023-01-22&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-22&until=2023-01-23&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-23&until=2023-01-24&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-24&until=2023-01-25&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-25&until=2023-01-26&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-26&until=2023-01-27&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-27&until=2023-01-28&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-28&until=2023-01-29&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-29&until=2023-01-30&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-30&until=2023-01-31&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-01-31&until=2023-02-01&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-01&until=2023-02-02&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-02&until=2023-02-03&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-03&until=2023-02-04&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-04&until=2023-02-05&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-05&until=2023-02-06&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-06&until=2023-02-07&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-07&until=2023-02-08&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-08&until=2023-02-09&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-09&until=2023-02-10&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-10&until=2023-02-11&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-11&until=2023-02-12&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-12&until=2023-02-13&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-13&until=2023-02-14&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-14&until=2023-02-15&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-15&until=2023-02-16&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-16&until=2023-02-17&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-17&until=2023-02-18&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-18&until=2023-02-19&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-19&until=2023-02-20&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-20&until=2023-02-21&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-21&until=2023-02-22&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-22&until=2023-02-23&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-23&until=2023-02-24&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-24&until=2023-02-25&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-25&until=2023-02-26&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-26&until=2023-02-27&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-27&until=2023-02-28&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-02-28&until=2023-03-01&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-01&until=2023-03-02&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-02&until=2023-03-03&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-03&until=2023-03-04&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-04&until=2023-03-05&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-05&until=2023-03-06&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-06&until=2023-03-07&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-07&until=2023-03-08&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-08&until=2023-03-09&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-09&until=2023-03-10&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-10&until=2023-03-11&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-11&until=2023-03-12&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-12&until=2023-03-13&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-13&until=2023-03-14&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-14&until=2023-03-15&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-15&until=2023-03-16&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-16&until=2023-03-17&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-17&until=2023-03-18&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-18&until=2023-03-19&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-19&until=2023-03-20&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-20&until=2023-03-21&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-21&until=2023-03-22&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-22&until=2023-03-23&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-23&until=2023-03-24&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-24&until=2023-03-25&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-25&until=2023-03-26&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-26&until=2023-03-27&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-27&until=2023-03-28&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-28&until=2023-03-29&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-29&until=2023-03-30&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-30&until=2023-03-31&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-03-31&until=2023-04-01&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-01&until=2023-04-02&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-02&until=2023-04-03&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-03&until=2023-04-04&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-04&until=2023-04-05&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-05&until=2023-04-06&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-06&until=2023-04-07&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-07&until=2023-04-08&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-08&until=2023-04-09&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-09&until=2023-04-10&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-10&until=2023-04-11&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-11&until=2023-04-12&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-12&until=2023-04-13&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-13&until=2023-04-14&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-14&until=2023-04-15&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-15&until=2023-04-16&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-16&until=2023-04-17&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-17&until=2023-04-18&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-18&until=2023-04-19&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-19&until=2023-04-20&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-20&until=2023-04-21&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-21&until=2023-04-22&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-22&until=2023-04-23&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-23&until=2023-04-24&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-24&until=2023-04-25&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-25&until=2023-04-26&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-26&until=2023-04-27&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-27&until=2023-04-28&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-28&until=2023-04-29&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-29&until=2023-04-30&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-04-30&until=2023-05-01&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-01&until=2023-05-02&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-02&until=2023-05-03&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-03&until=2023-05-04&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-04&until=2023-05-05&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-05&until=2023-05-06&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-06&until=2023-05-07&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-07&until=2023-05-08&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-08&until=2023-05-09&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-09&until=2023-05-10&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-10&until=2023-05-11&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-11&until=2023-05-12&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-12&until=2023-05-13&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-13&until=2023-05-14&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-14&until=2023-05-15&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-15&until=2023-05-16&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-16&until=2023-05-17&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-17&until=2023-05-18&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-18&until=2023-05-19&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-19&until=2023-05-20&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-20&until=2023-05-21&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-21&until=2023-05-22&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-22&until=2023-05-23&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-23&until=2023-05-24&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-24&until=2023-05-25&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-25&until=2023-05-26&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-26&until=2023-05-27&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-27&until=2023-05-28&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-28&until=2023-05-29&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-29&until=2023-05-30&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-30&until=2023-05-31&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-05-31&until=2023-06-01&near=
# https://nitter.net/search?f=tweets&q=entreprises%2Bvertes&since=2023-06-01&until=2023-06-02&near=
# https://nitter.net/search?f=tweets&q=transition%2Becologique&since=2023-01-01&until=2023-01-02&near=
# https://nitter.net/search?f=tweets&q=transition%2Becologique&since=2023-01-02&until=2023-01-03&near=
# https://nitter.net/search?f=tweets&q=transition%2Becologique&since=2023-01-03&until=2023-01-04&near=
# https://nitter.net/search?f=tweets&q=transition%2Becologique&since=2023-01-04&until=2023-01-05&near=
# https://nitter.net/search?f=tweets&q=transition%2Becologique&since=2023-01-05&until=2023-01-06&near=
# https://nitter.net/search?f=tweets&q=transition%2Becologique&since=2023-01-06&until=2023-01-07&near=
# https://nitter.net/search?f=tweets&q=transition%2Becologique&since=2023-01-07&until=2023-01-08&near=
# https://nitter.net/search?f=tweets&q=transition%2Becologique&since=2023-01-08&until=2023-01-09&near=
# ...
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-20&until=2023-01-21&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-21&until=2023-01-22&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-22&until=2023-01-23&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-23&until=2023-01-24&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-24&until=2023-01-25&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-25&until=2023-01-26&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-26&until=2023-01-27&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-27&until=2023-01-28&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-28&until=2023-01-29&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-29&until=2023-01-30&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-30&until=2023-01-31&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-01-31&until=2023-02-01&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-01&until=2023-02-02&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-02&until=2023-02-03&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-03&until=2023-02-04&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-04&until=2023-02-05&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-05&until=2023-02-06&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-06&until=2023-02-07&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-07&until=2023-02-08&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-08&until=2023-02-09&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-09&until=2023-02-10&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-10&until=2023-02-11&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-11&until=2023-02-12&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-12&until=2023-02-13&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-13&until=2023-02-14&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-14&until=2023-02-15&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-15&until=2023-02-16&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-16&until=2023-02-17&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-17&until=2023-02-18&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-18&until=2023-02-19&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-19&until=2023-02-20&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-20&until=2023-02-21&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-21&until=2023-02-22&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-22&until=2023-02-23&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-23&until=2023-02-24&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-24&until=2023-02-25&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-25&until=2023-02-26&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-26&until=2023-02-27&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-27&until=2023-02-28&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-02-28&until=2023-03-01&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-01&until=2023-03-02&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-02&until=2023-03-03&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-03&until=2023-03-04&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-04&until=2023-03-05&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-05&until=2023-03-06&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-06&until=2023-03-07&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-07&until=2023-03-08&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-08&until=2023-03-09&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-09&until=2023-03-10&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-10&until=2023-03-11&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-11&until=2023-03-12&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-12&until=2023-03-13&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-13&until=2023-03-14&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-14&until=2023-03-15&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-15&until=2023-03-16&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-16&until=2023-03-17&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-17&until=2023-03-18&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-18&until=2023-03-19&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-19&until=2023-03-20&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-20&until=2023-03-21&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-21&until=2023-03-22&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-22&until=2023-03-23&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-23&until=2023-03-24&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-24&until=2023-03-25&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-25&until=2023-03-26&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-26&until=2023-03-27&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-27&until=2023-03-28&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-28&until=2023-03-29&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-29&until=2023-03-30&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-30&until=2023-03-31&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-03-31&until=2023-04-01&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-01&until=2023-04-02&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-02&until=2023-04-03&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-03&until=2023-04-04&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-04&until=2023-04-05&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-05&until=2023-04-06&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-06&until=2023-04-07&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-07&until=2023-04-08&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-08&until=2023-04-09&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-09&until=2023-04-10&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-10&until=2023-04-11&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-11&until=2023-04-12&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-12&until=2023-04-13&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-13&until=2023-04-14&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-14&until=2023-04-15&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-15&until=2023-04-16&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-16&until=2023-04-17&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-17&until=2023-04-18&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-18&until=2023-04-19&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-19&until=2023-04-20&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-20&until=2023-04-21&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-21&until=2023-04-22&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-22&until=2023-04-23&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-23&until=2023-04-24&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-24&until=2023-04-25&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-25&until=2023-04-26&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-26&until=2023-04-27&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-27&until=2023-04-28&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-28&until=2023-04-29&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-29&until=2023-04-30&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-04-30&until=2023-05-01&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-01&until=2023-05-02&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-02&until=2023-05-03&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-03&until=2023-05-04&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-04&until=2023-05-05&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-05&until=2023-05-06&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-06&until=2023-05-07&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-07&until=2023-05-08&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-08&until=2023-05-09&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-09&until=2023-05-10&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-10&until=2023-05-11&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-11&until=2023-05-12&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-12&until=2023-05-13&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-13&until=2023-05-14&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-14&until=2023-05-15&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-15&until=2023-05-16&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-16&until=2023-05-17&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-17&until=2023-05-18&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-18&until=2023-05-19&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-19&until=2023-05-20&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-20&until=2023-05-21&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-21&until=2023-05-22&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-22&until=2023-05-23&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-23&until=2023-05-24&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-24&until=2023-05-25&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-25&until=2023-05-26&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-26&until=2023-05-27&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-27&until=2023-05-28&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-28&until=2023-05-29&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-29&until=2023-05-30&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-30&until=2023-05-31&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-05-31&until=2023-06-01&near=
# https://nitter.net/search?f=tweets&q=sobri%C3%A9t%C3%A9%2B%C3%A9nerg%C3%A9tique&since=2023-06-01&until=2023-06-02&near=

# %%
# Concaténer les résultats de chaque jour dans un unique DataFrame
df_all_tweets = pd.concat(results)

# %%
df_all_tweets
# Out:
#                                               Content  \
# 0   Ah, en effet...\nLa transition écologique est ...
# 1   Méthode pour une transition écologique dans le...
# 2   Enseignement agricole et transition écologique...
# 3   la pollueuse de notre planète qui a des intérê...
# 4   Quand la transition écologique bouscule la pol...
# ..                                                ...
# 15  #decarbononsSeineEure\n\n3eme table ronde sur ...
# 16  Le numérique 🖥️  peut-il soutenir la #sobriété...
# 17  Ils prouvent que le monde sera à l'heure sur l...
# 18  Acteur de la ressource en eau, promoteur d’un ...
# 19  #CcDeLaRegionDeCondrieu - CONFÉRENCE GRATUITE ...
#
#                           Date                                           Link  \
# 0   Jan 1, 2023 · 11:52 PM UTC   /PaysagesIroise/status/1609699207169941505#m
# 1   Jan 1, 2023 · 11:29 PM UTC   /InfosEducation/status/1609693388776906752#m
# 2   Jan 1, 2023 · 11:03 PM UTC  /VIENSflashmober/status/1609686785084493826#m
# 3   Jan 1, 2023 · 10:26 PM UTC      /LIBERTE1311/status/1609677427223007232#m
# 4   Jan 1, 2023 · 10:21 PM UTC         /PACOLLOT/status/1609676117555781634#m
# ..                         ...                                            ...
# 15   Jun 1, 2023 · 9:49 AM UTC        /LePoleTES/status/1664207513951109121#m
# 16   Jun 1, 2023 · 9:10 AM UTC          /FLievyn/status/1664197785166438402#m
# 17   Jun 1, 2023 · 8:55 AM UTC       /GlennAndr7/status/1664193820966150144#m
# 18   Jun 1, 2023 · 8:24 AM UTC     /vnf_officiel/status/1664186202155634688#m
# 19   Jun 1, 2023 · 6:32 AM UTC     /Infoflash_69/status/1664158046535274497#m
#
#                          Utilisateur    Utilisateur_id Comments Retweets  \
# 0       Sauvegarde Paysages d'Iroise   @PaysagesIroise
# 1              Education & Formation   @InfosEducation
# 2                     Etat d'urgence  @VIENSflashmober
# 3                               eddy      @LIBERTE1311
# 4                Pierre-Alain Collot         @PACOLLOT
# ..                               ...               ...      ...      ...
# 15                          Pôle TES        @LePoleTES                 2
# 16                   Florence.Lievyn          @FLievyn                 1
# 17                       Glenn André       @GlennAndr7        1
# 18  VNF - Voies navigables de France     @vnf_officiel                 3
# 19                   🇫🇷 InfoFlash_69     @Infoflash_69
#
#    Quotes Hearts
# 0              1
# 1
# 2
# 3              1
# 4
# ..    ...    ...
# 15             4
# 16             3
# 17             2
# 18             1
# 19
#
# [52162 rows x 9 columns]

# %%
# Fonction pour nettoyer les dates
def clean_date(date_string):
    if pd.isnull(date_string):
        return date_string
    cleaned_string = date_string.replace("¬∑", "")
    cleaned_string = date_string.replace("Â·", "")
    cleaned_string = date_string.replace("Ā", "")
    cleaned_string = date_string.replace("·", "")
    return cleaned_string.strip()

# Nettoyer la colonne 'Date'
df_all_tweets['Date'] = df_all_tweets['Date'].apply(lambda x: clean_date(x))

# Convertir la colonne 'Date' en format datetime
df_all_tweets['Date'] = pd.to_datetime(df_all_tweets['Date'], format="%b %d, %Y %I:%M %p UTC", errors='coerce')

# Créer les colonnes 'Jour', 'Mois' et 'Année'
df_all_tweets['Jour'] = df_all_tweets['Date'].dt.day
df_all_tweets['Mois'] = df_all_tweets['Date'].dt.month
df_all_tweets['Année'] = df_all_tweets['Date'].dt.year

# Convertir les colonnes 'Jour', 'Mois' et 'Année' en entiers
df_all_tweets['Jour'] = df_all_tweets['Jour'].apply(lambda x: str(int(x)) if not pd.isnull(x) else '')
df_all_tweets['Mois'] = df_all_tweets['Mois'].apply(lambda x: str(int(x)) if not pd.isnull(x) else '')
df_all_tweets['Année'] = df_all_tweets['Année'].apply(lambda x: str(int(x)) if not pd.isnull(x) else '')

# Convertir la colonne 'Date' en format JJ/MM/AAAA
df_all_tweets['Date'] = df_all_tweets['Date'].dt.strftime("%d/%m/%Y")

# %%
df_all_tweets = df_all_tweets.reindex(columns=['Content', 'Date', 'Jour', 'Mois', 'Année', 'Link', 'Utilisateur', 'Utilisateur_id', 'Comments', 'Retweets', 'Quotes', 'Hearts'])

# %%
df_all_tweets
# Out:
#                                               Content        Date Jour Mois  \
# 0   Ah, en effet...\nLa transition écologique est ...  01/01/2023    1    1
# 1   Méthode pour une transition écologique dans le...  01/01/2023    1    1
# 2   Enseignement agricole et transition écologique...  01/01/2023    1    1
# 3   la pollueuse de notre planète qui a des intérê...  01/01/2023    1    1
# 4   Quand la transition écologique bouscule la pol...  01/01/2023    1    1
# ..                                                ...         ...  ...  ...
# 15  #decarbononsSeineEure\n\n3eme table ronde sur ...  01/06/2023    1    6
# 16  Le numérique 🖥️  peut-il soutenir la #sobriété...  01/06/2023    1    6
# 17  Ils prouvent que le monde sera à l'heure sur l...  01/06/2023    1    6
# 18  Acteur de la ressource en eau, promoteur d’un ...  01/06/2023    1    6
# 19  #CcDeLaRegionDeCondrieu - CONFÉRENCE GRATUITE ...  01/06/2023    1    6
#
#    Année                                           Link  \
# 0   2023   /PaysagesIroise/status/1609699207169941505#m
# 1   2023   /InfosEducation/status/1609693388776906752#m
# 2   2023  /VIENSflashmober/status/1609686785084493826#m
# 3   2023      /LIBERTE1311/status/1609677427223007232#m
# 4   2023         /PACOLLOT/status/1609676117555781634#m
# ..   ...                                            ...
# 15  2023        /LePoleTES/status/1664207513951109121#m
# 16  2023          /FLievyn/status/1664197785166438402#m
# 17  2023       /GlennAndr7/status/1664193820966150144#m
# 18  2023     /vnf_officiel/status/1664186202155634688#m
# 19  2023     /Infoflash_69/status/1664158046535274497#m
#
#                          Utilisateur    Utilisateur_id Comments Retweets  \
# 0       Sauvegarde Paysages d'Iroise   @PaysagesIroise
# 1              Education & Formation   @InfosEducation
# 2                     Etat d'urgence  @VIENSflashmober
# 3                               eddy      @LIBERTE1311
# 4                Pierre-Alain Collot         @PACOLLOT
# ..                               ...               ...      ...      ...
# 15                          Pôle TES        @LePoleTES                 2
# 16                   Florence.Lievyn          @FLievyn                 1
# 17                       Glenn André       @GlennAndr7        1
# 18  VNF - Voies navigables de France     @vnf_officiel                 3
# 19                   🇫🇷 InfoFlash_69     @Infoflash_69
#
#    Quotes Hearts
# 0              1
# 1
# 2
# 3              1
# 4
# ..    ...    ...
# 15             4
# 16             3
# 17             2
# 18             1
# 19
#
# [52162 rows x 12 columns]

# %%
import csv

df_all_tweets.to_csv(
    'PPD_ALL_Scrapping.csv',
    sep=';',
    index=False,
    encoding='utf-8-sig',
    #quoting=csv.QUOTE_NONE,
    #escapechar='\\'
)

# %% [markdown]
# # Selenium - Code avec 1 jour (demo)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://nitter.net/search?f=tweets&q=transition+%C3%A9nerg%C3%A9tique+energetique&since=2023-04-20&until=2023-04-21&near=")
html = driver.page_source

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
# extraire les informations de chaque tweet
tweet_contents = []
tweet_dates = []
tweet_links = []
tweet_names = []
comment_stats = []
retweet_stats = []
quote_stats = []
heart_stats = []

for tweet in soup.find_all('div', {'class': 'timeline-item'}):
    # contenu du tweet
    content = tweet.find('div', {'class': 'tweet-content'}).text.strip()
    tweet_contents.append(content)
    
    # date du tweet
    date = tweet.find('span', {'class': 'tweet-date'}).a['title']
    tweet_dates.append(date)
    
    # lien du tweet
    link = tweet.find('a', {'class': 'tweet-link'})['href']
    tweet_links.append(link)
    
    # nom (title) du tweet
    name = tweet.find('a', {'class': 'fullname'})['title']
    tweet_names.append(name)
    
    # statistiques
    stats = tweet.find_all('div', {'class': 'icon-container'})
    comment_stats.append(stats[0].text.strip())
    retweet_stats.append(stats[1].text.strip())
    quote_stats.append(stats[2].text.strip())
    heart_stats.append(stats[3].text.strip())

# %%
# créer un dataframe pandas à partir des listes d'informations
df = pd.DataFrame({
    'Content': tweet_contents,
    'Date': tweet_dates,
    'Link': tweet_links,
    'Utilisateur': tweet_names,
    'Comments': comment_stats,
    'Retweets': retweet_stats,
    'Quotes': quote_stats,
    'Hearts': heart_stats
})

# %%
df
# Out:
#                                               Content  \
# 0   RATP (Bus)\n\n🌿Depuis le 19/04/23, la ligne 14...
# 1   Le rapport rendu ce vendredi à @AgnesRunacher,...
# 2   📢 Défis de l'employabilité avec la transition ...
# 3   « C’est un pied de nez au Québec. On se fait d...
# 4   Chère @_EvaSas En #Allemagne ils n'ont pas att...
# 5   📃 Le 1er conseil d’administration de la Fondat...
# 6   Métaux stratégiques de l'Afrique pour la trans...
# 7   il est juste que les acteurs publics[…]soient ...
# 8   Roland Lescure et de la ministre de la transit...
# 9   Plus de 10 millions de morts, au moins 500 000...
# 10  d'où l'hydrogène pour stocker les Enr, la Fran...
# 11  LA TRANSITION ENERGETIQUE : 5/05 - 10H/11H  📷 ...
# 12  Après le rejet de la loi sur le CO2, l'UDC veu...
# 13  Juste avant de quitter @ZenonResearch j’ai été...
# 14  Concours Ministère de la Transition Energétiqu...
# 15  Lu sur France 24 : "TRANSITION ÉNERGÉTIQUE\nAr...
# 16  Appel de l'intersyndicale de Tricastin dans la...
#
#                            Date  \
# 0   Apr 20, 2023 · 11:14 PM UTC
# 1   Apr 20, 2023 · 10:45 PM UTC
# 2   Apr 20, 2023 · 10:19 PM UTC
# 3    Apr 20, 2023 · 9:22 PM UTC
# 4    Apr 20, 2023 · 8:56 PM UTC
# 5    Apr 20, 2023 · 7:11 PM UTC
# 6    Apr 20, 2023 · 6:56 PM UTC
# 7    Apr 20, 2023 · 6:49 PM UTC
# 8    Apr 20, 2023 · 6:20 PM UTC
# 9    Apr 20, 2023 · 6:20 PM UTC
# 10   Apr 20, 2023 · 6:07 PM UTC
# 11   Apr 20, 2023 · 6:00 PM UTC
# 12   Apr 20, 2023 · 5:54 PM UTC
# 13   Apr 20, 2023 · 5:49 PM UTC
# 14   Apr 20, 2023 · 5:49 PM UTC
# 15   Apr 20, 2023 · 5:46 PM UTC
# 16   Apr 20, 2023 · 5:34 PM UTC
#
#                                              Link  \
# 0   /chanstransports/status/1649189726593732608#m
# 1     /ChamboncelBen/status/1649182448842833921#m
# 2          /IFDD_OIF/status/1649176003158192128#m
# 3         /seblemire/status/1649161573867352066#m
# 4      /PIERREMAURIN/status/1649154996355624967#m
# 5    /FondationOpenC/status/1649128606319214593#m
# 6      /energiemines/status/1649124953923387417#m
# 7        /JCondamine/status/1649123244178276383#m
# 8   /DanielM11626471/status/1649115758109007875#m
# 9       /EpopoYanick/status/1649115722583359492#m
# 10       /fun_papatt/status/1649112543913230337#m
# 11      /URIOPSS_BFC/status/1649110686289788931#m
# 12  /WeerachaiJaila1/status/1649109414048038918#m
# 13          /Gregdt1/status/1649108074626416640#m
# 14    /tahiriyouness/status/1649108039700557824#m
# 15        /31mai2022/status/1649107357220192256#m
# 16         /JPguedas/status/1649104300809781274#m
#
#                                           Utilisateur Comments Retweets  \
# 0                         Claude-Henry & ses périples        2        6
# 1                                   Benoît Chamboncel
# 2                                                IFDD                 2
# 3                                    Sébastien Lemire        2
# 4                                       Pierre Maurin                 1
# 5                                    Fondation OPEN-C        1        1
# 6                                    Magazine Energie
# 7                   Jean Condamine 🇫🇷 🇪🇸 🇬🇧 👍🍻🍺🤔🧐😉👌🥂🍾        2        5
# 8                                 Daniel Moore 🇷🇺🇷🇺🇷🇺        1        1
# 9                                        Epopo yanick                 1
# 10                                       John3 Major3
# 11                                        URIOPSS BFC
# 12                                Weerachai Jailangka
# 13                                  Greg De Temmerman                 3
# 14                                      أخبار الوظيفة
# 15                                    Français Debout
# 16  Sous secrétaire d'étable à l'épanouissement Bovin                 2
#
#    Quotes Hearts
# 0       1     47
# 1      22      1
# 2              5
# 3              1
# 4              2
# 5              4
# 6
# 7             22
# 8              4
# 9              1
# 10
# 11
# 12
# 13      1     10
# 14
# 15
# 16             4

# %%
# Fonction pour convertir la date dans le bon format
def convert_date(date_string):
    date_obj = datetime.datetime.strptime(date_string.split(' · ')[0], "%b %d, %Y")
    return date_obj.strftime("%d/%m/%Y")

# Convertir la colonne 'Date' en format datetime
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split(' · ')[0]), format='%b %d, %Y')

# Créer les colonnes 'Jour', 'Mois' et 'Année'
df['Jour'] = df['Date'].dt.day
df['Mois'] = df['Date'].dt.month
df['Année'] = df['Date'].dt.year

# Convertir la colonne 'Date' en format JJ/MM/AAAA
df['Date'] = df['Date'].apply(lambda x: convert_date(x.strftime("%b %d, %Y")))

# %%
df = df.reindex(columns=['Content', 'Date', 'Jour', 'Mois', 'Année', 'Link', 'Utilisateur','Comments', 'Retweets', 'Quotes', 'Hearts'])

# %%
df
# Out:
#                                               Content        Date  Jour  Mois  \
# 0   RATP (Bus)\n\n🌿Depuis le 19/04/23, la ligne 14...  20/04/2023    20     4
# 1   Le rapport rendu ce vendredi à @AgnesRunacher,...  20/04/2023    20     4
# 2   📢 Défis de l'employabilité avec la transition ...  20/04/2023    20     4
# 3   « C’est un pied de nez au Québec. On se fait d...  20/04/2023    20     4
# 4   Chère @_EvaSas En #Allemagne ils n'ont pas att...  20/04/2023    20     4
# 5   📃 Le 1er conseil d’administration de la Fondat...  20/04/2023    20     4
# 6   Métaux stratégiques de l'Afrique pour la trans...  20/04/2023    20     4
# 7   il est juste que les acteurs publics[…]soient ...  20/04/2023    20     4
# 8   Roland Lescure et de la ministre de la transit...  20/04/2023    20     4
# 9   Plus de 10 millions de morts, au moins 500 000...  20/04/2023    20     4
# 10  d'où l'hydrogène pour stocker les Enr, la Fran...  20/04/2023    20     4
# 11  LA TRANSITION ENERGETIQUE : 5/05 - 10H/11H  📷 ...  20/04/2023    20     4
# 12  Après le rejet de la loi sur le CO2, l'UDC veu...  20/04/2023    20     4
# 13  Juste avant de quitter @ZenonResearch j’ai été...  20/04/2023    20     4
# 14  Concours Ministère de la Transition Energétiqu...  20/04/2023    20     4
# 15  Lu sur France 24 : "TRANSITION ÉNERGÉTIQUE\nAr...  20/04/2023    20     4
# 16  Appel de l'intersyndicale de Tricastin dans la...  20/04/2023    20     4
#
#     Année                                           Link  \
# 0    2023  /chanstransports/status/1649189726593732608#m
# 1    2023    /ChamboncelBen/status/1649182448842833921#m
# 2    2023         /IFDD_OIF/status/1649176003158192128#m
# 3    2023        /seblemire/status/1649161573867352066#m
# 4    2023     /PIERREMAURIN/status/1649154996355624967#m
# 5    2023   /FondationOpenC/status/1649128606319214593#m
# 6    2023     /energiemines/status/1649124953923387417#m
# 7    2023       /JCondamine/status/1649123244178276383#m
# 8    2023  /DanielM11626471/status/1649115758109007875#m
# 9    2023      /EpopoYanick/status/1649115722583359492#m
# 10   2023       /fun_papatt/status/1649112543913230337#m
# 11   2023      /URIOPSS_BFC/status/1649110686289788931#m
# 12   2023  /WeerachaiJaila1/status/1649109414048038918#m
# 13   2023          /Gregdt1/status/1649108074626416640#m
# 14   2023    /tahiriyouness/status/1649108039700557824#m
# 15   2023        /31mai2022/status/1649107357220192256#m
# 16   2023         /JPguedas/status/1649104300809781274#m
#
#                                           Utilisateur Comments Retweets  \
# 0                         Claude-Henry & ses périples        2        6
# 1                                   Benoît Chamboncel
# 2                                                IFDD                 2
# 3                                    Sébastien Lemire        2
# 4                                       Pierre Maurin                 1
# 5                                    Fondation OPEN-C        1        1
# 6                                    Magazine Energie
# 7                   Jean Condamine 🇫🇷 🇪🇸 🇬🇧 👍🍻🍺🤔🧐😉👌🥂🍾        2        5
# 8                                 Daniel Moore 🇷🇺🇷🇺🇷🇺        1        1
# 9                                        Epopo yanick                 1
# 10                                       John3 Major3
# 11                                        URIOPSS BFC
# 12                                Weerachai Jailangka
# 13                                  Greg De Temmerman                 3
# 14                                      أخبار الوظيفة
# 15                                    Français Debout
# 16  Sous secrétaire d'étable à l'épanouissement Bovin                 2
#
#    Quotes Hearts
# 0       1     47
# 1      22      1
# 2              5
# 3              1
# 4              2
# 5              4
# 6
# 7             22
# 8              4
# 9              1
# 10
# 11
# 12
# 13      1     10
# 14
# 15
# 16             4

# %% [markdown]
# # Selenium - Code pour plusieurs jours

# %%
pip install webdriver_manager
# Out:
# Collecting webdriver_managerNote: you may need to restart the kernel to use updated packages.
#
#   Downloading webdriver_manager-3.8.6-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: requests in c:\users\ftg1\appdata\local\programs\python\python311\lib\site-packages (from webdriver_manager) (2.28.1)
# Collecting python-dotenv (from webdriver_manager)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: tqdm in c:\users\ftg1\appdata\local\programs\python\python311\lib\site-packages (from webdriver_manager) (4.64.1)
# Requirement already satisfied: packaging in c:\users\ftg1\appdata\local\programs\python\python311\lib\site-packages (from webdriver_manager) (22.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ftg1\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver_manager) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ftg1\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver_manager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ftg1\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver_manager) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ftg1\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver_manager) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\ftg1\appdata\local\programs\python\python311\lib\site-packages (from tqdm->webdriver_manager) (0.4.6)
# Installing collected packages: python-dotenv, webdriver_manager
# Successfully installed python-dotenv-1.0.0 webdriver_manager-3.8.6

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup
import pandas as pd
import datetime

# %%
# Date de début de la recherche
start_date = datetime.date(2023, 5, 1)

# Date de fin de la recherche
end_date = datetime.date(2023, 5, 2)

# Créer la liste des dates à parcourir
delta = datetime.timedelta(days=1)
dates = []
while start_date <= end_date:
    dates.append(start_date)
    start_date += delta

# %%
# Initialiser le webdriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Liste des données à récupérer
tweet_contents = []
tweet_dates = []
tweet_links = []
tweet_names = []
comment_stats = []
retweet_stats = []
quote_stats = []
heart_stats = []

# %%
# Boucle pour parcourir les pages pour chaque date
for date in dates:
    url = f"https://nitter.net/search?f=tweets&q=transition+%C3%A9nerg%C3%A9tique+energetique&since={date}&until={date+delta}&near="
    driver.get(url)
    while True:
        # Extraire les informations de chaque tweet sur la page
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        for tweet in soup.find_all('div', {'class': 'timeline-item'}):
            # Contenu du tweet
            content = tweet.find('div', {'class': 'tweet-content'}).text.strip()
            tweet_contents.append(content)
            
            # Date du tweet
            date = tweet.find('span', {'class': 'tweet-date'}).a['title']
            tweet_dates.append(date)
            
            # Lien du tweet
            link = tweet.find('a', {'class': 'tweet-link'})['href']
            tweet_links.append(link)
            
            # Nom (title) du tweet
            name = tweet.find('a', {'class': 'fullname'})['title']
            tweet_names.append(name)
            
            # Statistiques
            stats = tweet.find_all('div', {'class': 'icon-container'})
            comment_stats.append(stats[0].text.strip())
            retweet_stats.append(stats[1].text.strip())
            quote_stats.append(stats[2].text.strip())
            heart_stats.append(stats[3].text.strip())
        
        # Cliquer sur le bouton "Load more" si présent
        try:
            #load_more_button = driver.find_element_by_class_name("show-more").find_element_by_tag_name("a")
            #load_more_button = driver.find_elements(By.CLASS_NAME, "show-more")
            #load_more_button=load_more_button.find_elements(By.TAG_NAME, "a")
            #print(load_more_button)
            #load_more_button.click()
            #print(load_more_button[0].text)
            #driver.execute_script("arguments[0].click();", load_more_button);
            
            # get element 
            element = driver.find_element_by_link_text("Load more")
            print(element)
            # click the element
            element.click()
            
        except:
            break

# %%
# Créer un dataframe pandas avec les données récupérées
df = pd.DataFrame({
    'Content': tweet_contents,
    'Date': tweet_dates,
    'Link': tweet_links,
    'Utilisateur': tweet_names,
    'Comments': comment_stats,
    'Retweets': retweet_stats,
    'Quotes': quote_stats,
    'Hearts': heart_stats
})

# %%
# Fonction pour convertir la date dans le bon format
def convert_date(date_string):
    date_obj = datetime.datetime.strptime(date_string.split(' · ')[0], "%b %d, %Y")
    return date_obj.strftime("%d/%m/%Y")

# Convertir la colonne 'Date' en format datetime
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split(' · ')[0]), format='%b %d, %Y')

# Créer les colonnes 'Jour', 'Mois' et 'Année'
df['Jour'] = df['Date'].dt.day
df['Mois'] = df['Date'].dt.month
df['Année'] = df['Date'].dt.year

# Convertir la colonne 'Date' en format JJ/MM/AAAA
df['Date'] = df['Date'].apply(lambda x: convert_date(x.strftime("%b %d, %Y")))

# %%
df = df.reindex(columns=['Content', 'Date', 'Jour', 'Mois', 'Année', 'Link', 'Utilisateur','Comments', 'Retweets', 'Quotes', 'Hearts'])

# %%
df
# Out:
#                                               Content        Date  Jour  Mois  \
# 0   Pourquoi le Maroc est important pour la transi...  01/05/2023     1     5
# 1   dans le sable du désert - et des plans ambitie...  01/05/2023     1     5
# 2   Repenser la transition énergétique : Le menson...  01/05/2023     1     5
# 3   Là j'approuve, ça n'est pas une oeuvre d'art q...  01/05/2023     1     5
# 4   Oui, mais non puisque l'Allemagne se donne les...  01/05/2023     1     5
# 5   Pas la peine de demander qui vous suivez polit...  01/05/2023     1     5
# 6   Participez à la transition énergétique avec ce...  01/05/2023     1     5
# 7   mes félicitations ! votre livre, très utile po...  01/05/2023     1     5
# 8   Besoin en investissement, en travailleurs, con...  01/05/2023     1     5
# 9   "transition écologique", ou encore "transition...  01/05/2023     1     5
# 10  Félicitations à toutes les universités! Nous s...  01/05/2023     1     5
# 11  Transition énergétique suisse: Des histoires d...  01/05/2023     1     5
# 12  Transition énergétique suisse: Des histoires d...  01/05/2023     1     5
# 13  Transition énergétique suisse: Des histoires d...  01/05/2023     1     5
# 14  Transition énergétique : « La comptabilité des...  01/05/2023     1     5
# 15  Super plus que 220M, 2 ans de baisse wow ! Et ...  01/05/2023     1     5
# 16  Le @POTUS sera au sommet du @G7 au Japon du 19...  01/05/2023     1     5
# 17  C’est surtout fait pour financer les deux plus...  01/05/2023     1     5
# 18  Focalisés sur la transition énergétique liée à...  01/05/2023     1     5
# 19  "Taka nadifa" : Un des piliers de la transitio...  02/05/2023     2     5
# 20  Nous avons sous nos pieds la plus grande resso...  02/05/2023     2     5
# 21  La France dans l'impasse, et  l'Allemagne qui ...  02/05/2023     2     5
# 22  🇩🇪 Centrale à charbon de Neurath - Première ét...  02/05/2023     2     5
# 23  “Taka nadifa” : Un des piliers de la transitio...  02/05/2023     2     5
# 24  Zones à faibles émissions #zfe ne sont que les...  02/05/2023     2     5
# 25  Les remboursements de MaPrimeRénov’ se font pa...  02/05/2023     2     5
# 26  via @franceinfo : En Haute-Vienne, la petite h...  02/05/2023     2     5
# 27  Sans les moyens de financer une transition éne...  02/05/2023     2     5
# 28  Réussir la transition énergétique, c’est valor...  02/05/2023     2     5
# 29  Besoin en investissement, en travailleurs, con...  02/05/2023     2     5
# 30  La charte ravalement de façade s'adapte aux év...  02/05/2023     2     5
# 31  Réunion sur le climat et l'énergie des princip...  02/05/2023     2     5
# 32  Au R'Haine, tant qu'à faire on torpille les ra...  02/05/2023     2     5
# 33  Et tant que le fret ferroviaire ne sera pas gé...  02/05/2023     2     5
# 34  Il est question de discuter notamment sur le #...  02/05/2023     2     5
# 35  L'énergie est chère, et voilà que la transitio...  02/05/2023     2     5
# 36  Comment utiliser la directive #CSRD comme levi...  02/05/2023     2     5
#
#     Année                                           Link  \
# 0    2023       /Rozlbrahim/status/1653155503642402821#m
# 1    2023       /Rozlbrahim/status/1653155505852801024#m
# 2    2023      /PEGE_french/status/1653127278828691457#m
# 3    2023  /marco_il_biondo/status/1653119911894327302#m
# 4    2023       /Djoanarcho/status/1653111091021463552#m
# 5    2023         /ceditpro/status/1653101214333034514#m
# 6    2023     /GreenBois_fr/status/1653093514144538632#m
# 7    2023    /michel_Halpes/status/1653090639108620289#m
# 8    2023  /FR_Conversation/status/1653090552382992384#m
# 9    2023          /5gLinky/status/1653084728046632978#m
# 10   2023        /CanadaOSC/status/1653077201602985984#m
# 11   2023       /24heuresch/status/1653075695411826689#m
# 12   2023        /tdgGeneve/status/1653074943238893568#m
# 13   2023            /tdgch/status/1653074942479724544#m
# 14   2023   /ADERAriverains/status/1653072828114116609#m
# 15   2023           /NEM613/status/1653060278983032832#m
# 16   2023    /USAenFrancais/status/1653057995675148294#m
# 17   2023  /SaccageGuada971/status/1653050759812923399#m
# 18   2023        /DoGui3891/status/1653043215165972483#m
# 19   2023    /AlgeriaHerald/status/1653543148797440001#m
# 20   2023  /jeanluclacroix7/status/1653527602898915332#m
# 21   2023       /electractu/status/1653510540092751872#m
# 22   2023  /PierreCazeneuve/status/1653489138153271298#m
# 23   2023        /fibladifr/status/1653484258495987713#m
# 24   2023        /jplecomti/status/1653481504251453440#m
# 25   2023      /infofrance2/status/1653474437898072064#m
# 26   2023    /leconteclaire/status/1653471775395651584#m
# 27   2023   /Banquemondiale/status/1653459344082751488#m
# 28   2023     /SoniaVerrier/status/1653457022153572353#m
# 29   2023  /FR_Conversation/status/1653456811201028096#m
# 30   2023      /Mairie9Lyon/status/1653456025716965381#m
# 31   2023    /Richard_Loyen/status/1653451564772622341#m
# 32   2023          /p_saury/status/1653449734336413710#m
# 33   2023  /Pierreapolitiqu/status/1653446327215194123#m
# 34   2023   /AllemagneauGAB/status/1653444547844636684#m
# 35   2023       /crayonmine/status/1653442046974099487#m
# 36   2023          /ahguena/status/1653441886751686657#m
#
#                                    Utilisateur Comments Retweets Quotes Hearts
# 0                                    인생은 계속됩니다        1                      1
# 1                                    인생은 계속됩니다        1                      1
# 2                                  Mösl Roland
# 3                              Marco il Biondo
# 4                                    BZH 🏴‍☠️🏴
# 5                                       cedric
# 6                                   Green Bois
# 7       Michel Cranga climat et responsabilité        2                      3
# 8                      The Conversation France                               2
# 9                    Stop Linky-5G Montpellier                               2
# 10                 Canada’s Ocean Supercluster
# 11                                   24 heures
# 12                            L'actu genevoise        1        1             1
# 13                           Tribune de Genève
# 14                                       ADERA
# 15                                       NEM&6        1
# 16                             USA en Français                10      7      1
# 17                             Baudouin Quatre        1                      1
# 18                              Dorian Guinard        1       17            34
# 19  الجزائر محروسة AlgérieInformations.com🇩🇿🇺🇸
# 20                            jean-luc lacroix
# 21                                    Alex 🐝 🔻        3
# 22                            Pierre Cazeneuve                71     93     11
# 23                             fibladi Algérie
# 24                                          jp
# 25                               Info France 2                 3      2      3
# 26                              Claire Leconte
# 27                             Banque mondiale        1        5            12
# 28                               Sonia Verrier                               1
# 29                     The Conversation France                 4             3
# 30                           Mairie du 9e Lyon        1
# 31                               Richard Loyen                 2             3
# 32                                Pierre SAURY
# 33                                     Coudray
# 34                          Allemagne au Gabon
# 35                               crayonlazer 🚩
# 36                              Ahmed Guenaoui                 1      3

# %% [markdown]
# # Brute force acteurs - Stats des acteurs (MAJ suite à sécurité Nitter)

# %%
# Chargement du dictionnaire des acteurs
dict_acteurs = df_all_tweets

# Garder que les utilisateurs uniques
dict_acteurs_unique = dict_acteurs.drop_duplicates(subset=['Utilisateur_id'])['Utilisateur_id'].to_list()
dict_acteurs_unique
# Out:
# ['@PaysagesIroise',
#  '@InfosEducation',
#  '@VIENSflashmober',
#  '@LIBERTE1311',
#  '@PACOLLOT',
#  '@verolive83',
#  '@Hergastul',
#  '@PatrickGlesener',
#  '@giOrdanoB6946',
#  '@randomie7i',
#  '@Marie08979035',
#  '@JeannotMbaya',
#  '@latulipenoire31',
#  '@Olivancalderone',
#  '@MySweetimmo',
#  '@LaurencePalais',
#  '@PMonoxyle',
#  '@MendiniNassim',
#  '@DavidBorie4',
#  '@BARLANicolas1',
#  '@Ortofon76',
#  '@Prefet49',
#  '@sophie_bussiere',
#  '@lemainelibre',
#  '@Actuenviro',
#  '@AudreyHenocque',
#  '@eco_actu',
#  '@SartheInfos',
#  '@groum_groum',
#  '@Babapolitique',
#  '@Q_deBremond',
#  '@RomainLaveau',
#  '@FrexitOtanExit',
#  '@Cesarmand',
#  '@o_environnement',
#  '@LaTribune',
#  '@LCI',
#  '@imperma1914',
#  '@ChristopheBechu',
#  '@FredBesnard',
#  '@Trunkhanwow',
#  '@UnivDroit_EDD',
#  '@TLConseil',
#  '@favier_florent',
#  '@deslnfor',
#  '@Benjam1Lucas',
#  '@shilderi',
#  '@Vivien_PI',
#  '@DorianBianco07',
#  '@LouisLghni',
#  '@Lejeune_paris',
#  '@communiquaction',
#  '@FrancoisBulloc1',
#  '@jeremyerline',
#  '@EadgGdea',
#  '@FabriceRivet',
#  '@SachaMaunier',
#  '@JuliaCerisi',
#  '@melggo',
#  '@iwona46',
#  '@ChaBahuon',
#  '@antoinecaplan',
#  '@HachaniNaima',
#  '@m_Romagnani',
#  '@LibertyLoveFr',
#  '@reix_toine',
#  '@JeunesseNupes',
#  '@Antoine0667Best',
#  '@Arr_Verdun',
#  '@DarkPhoenix9666',
#  '@LP641',
#  '@jnbarrot',
#  '@RDelinfo',
#  '@NoamLeandri',
#  '@benoitbonte',
#  '@VeloBucVGP',
#  '@VonbraunWerner',
#  '@Firenault',
#  '@claran55',
#  '@Goulran_',
#  '@baceau',
#  '@ademe',
#  '@ChristVdbPro',
#  '@Madininair972',
#  '@systemcruyff',
#  '@escaledenuit',
#  '@Jean_LucFUGIT',
#  '@24matins',
#  '@Pour_Gagner_35',
#  '@jacquesantoine',
#  '@X345__',
#  '@ElisabethLavill',
#  '@lemonde_campus',
#  '@AirMilarsky',
#  '@JeanPierreDESHA',
#  '@MetropoliticBot',
#  '@MyriamVillert',
#  '@luccarvounas',
#  '@Renaud_83990',
#  '@auvergne_infos',
#  '@HenryM_63',
#  '@a_leboeuf',
#  '@DavidLegros33',
#  '@andreaxlubeck',
#  '@Vincent48557733',
#  '@Valiryus',
#  '@villedemougins',
#  '@vinougradus',
#  '@FoncelJerome',
#  '@IPSL_outreach',
#  '@NicolNogent',
#  '@BELLATFoot',
#  '@baffeur77',
#  '@BoudPrototype',
#  '@MasterCEDDETE',
#  '@mpatrick21',
#  '@F3PaysdelaLoire',
#  '@adsaum',
#  '@Noelherve5',
#  '@CabinetAgcr',
#  '@MargauxVIDAL1',
#  '@XhiphiasG',
#  '@ville_chaville',
#  '@RicolotContact',
#  '@Befalimpertinen',
#  '@Cdanslair',
#  '@MarcoMonigaAtos',
#  '@FlorenceBlatrix',
#  '@TPoulinier',
#  '@JouveauM',
#  '@AxThV',
#  '@jchapuis',
#  '@FNAIM_Picardie',
#  '@Infos_Dijon',
#  '@ze_flower',
#  '@michelsalion',
#  '@Pasunmouton2',
#  '@stanley_kub',
#  '@Mr_Zakka',
#  '@BSR_Associes',
#  '@Boiscom',
#  '@MarieCasan',
#  '@sterdyniak',
#  '@ColineSomek',
#  '@JulienGossa',
#  '@Pandalatesta',
#  '@RomannKer',
#  '@franceEcoMag',
#  '@Hemail_79',
#  '@LaurentAlfonso',
#  '@ArnCollignon',
#  '@lesradicaux_',
#  '@365jeuxenfamil1',
#  '@rlarvent',
#  '@rococo321',
#  '@dlbrgn',
#  '@cci_ardennes',
#  '@dominique_meda',
#  '@SophieBellon',
#  '@frlinget',
#  '@jedy00075',
#  '@fdecoster',
#  '@gyrovaguerie',
#  '@PierreCazeneuve',
#  '@EricSartori3',
#  '@jmvittori',
#  '@RE_RueilMalmais',
#  '@geholf',
#  '@atterres',
#  '@PhilippeBUERCH',
#  '@GIRcontact',
#  '@BusinessBourse',
#  '@AnneMarieJean1',
#  '@JaneOfArc6',
#  '@eelvParis10',
#  '@jamy_william',
#  '@7Milx1',
#  '@JCEV15',
#  '@LaurePressac',
#  '@LDinclaux',
#  '@RL_Patriote',
#  '@ArnaudAbel',
#  '@GregIenco',
#  '@PatDucratin',
#  '@greenvincent',
#  '@RobyAgathe',
#  '@Nikki_Sane',
#  '@Solange__C',
#  '@Departement_971',
#  '@presseocean',
#  '@YoussefDoghmane',
#  '@JadoreMontreal',
#  '@PiNetworkFrance',
#  '@clesdusocial',
#  '@amandine_ynwa',
#  '@Maxime92160',
#  '@EcoloParis19',
#  '@lailatov',
#  '@MHAmiable',
#  '@JohnMitchell4x8',
#  '@Mikaa_H2',
#  '@FuriousKoen',
#  '@rosemarie4710',
#  '@ulyssedorioz',
#  '@IamEntry',
#  '@JM_Verchere',
#  '@laurentdejoie',
#  '@EyquemLeonard',
#  '@StanGuerini',
#  '@Mobrooo',
#  '@ManciniIsabelle',
#  '@marcgrosman75',
#  '@FindinLanguedoc',
#  '@S_Revages',
#  '@SebStanBono',
#  '@LeDL737401',
#  '@ademe_bretagne',
#  '@NicolasKlatka',
#  '@flyCSI',
#  '@pabouger',
#  '@Spike2577',
#  '@JeremieLandreau',
#  '@RaynaldBernier',
#  '@CabinetGsell',
#  '@FdeRugy',
#  '@FairPlay4Planet',
#  '@MartinFierro769',
#  '@Ecoyako_',
#  '@phenixfr',
#  '@SimpleF12656939',
#  '@ATokenInvestor',
#  '@nave_va',
#  '@BenjaminTeoule',
#  '@AdriendeVlt',
#  '@ch_lemercier',
#  '@MoukouB',
#  '@Melenchon4Ever',
#  '@CecileVignesM',
#  '@Lacjoe1',
#  '@ecoleiet',
#  '@vincent_monot',
#  '@PHD442',
#  '@GHClamart',
#  '@FabienneGrebert',
#  '@leparisien2024',
#  '@lp_materre',
#  '@DeremeAvocat',
#  '@KimKimuntu',
#  '@pascal_mulegwa',
#  '@acprdc_Officiel',
#  '@Linossier7',
#  '@meteo60',
#  '@Lamasticot__',
#  '@haricotsbleus',
#  '@RaymondBykouko',
#  '@aeros_wing',
#  '@franckcourchamp',
#  '@Victor_obrt',
#  '@laulecoeur',
#  '@anne_sicard',
#  '@lau68951920',
#  '@Stonks_Corp',
#  '@TabouleAAAAAAAH',
#  '@matgautier',
#  '@LucasPetit92',
#  '@homocommuniste',
#  '@voxjaen',
#  '@LEPETITSteph',
#  '@ChMerchadou',
#  '@LoucasPinto1',
#  '@vinzradio',
#  '@kevCi3',
#  '@fnadac',
#  '@PatrickMonin71',
#  '@ABPtwit',
#  '@Eleazar_jd',
#  '@ThomasL18174027',
#  '@Cmo351',
#  '@fred_mrs',
#  '@chateau_gontier',
#  '@matzenox',
#  '@DudesertFred',
#  '@CRECQ',
#  '@GregRoquett',
#  '@AlexisJanicot',
#  '@dm_petit',
#  '@Canope_40',
#  '@VRwatchingU',
#  '@TanShanLiMTL',
#  '@chanezherbanne',
#  '@sophiepiard',
#  '@HugCharbonneau',
#  '@Burlesque_32',
#  '@EmmanFernandes',
#  '@didjule',
#  '@VilledeChenove',
#  '@ChloeClair_namR',
#  '@Izidra_',
#  '@danlert',
#  '@VicGranier',
#  '@Ccesoir',
#  '@tcoiffeurjustes',
#  '@ChrisLavaquerie',
#  '@AnneTallineau',
#  '@SoniaBEKO',
#  '@HMassenet',
#  '@corsenetinfos',
#  '@EricKrezel',
#  '@GreenpeaceTours',
#  '@RANCHEREP',
#  '@lepenenchon',
#  '@SalifKO31547825',
#  '@WelterDelphine',
#  '@lowtechs',
#  '@TransitionsEco',
#  '@netguide',
#  '@FP_Champagne',
#  '@RV_Joly',
#  '@MajidZiraoui',
#  '@B_SMART_TV',
#  '@nutriac',
#  '@aure79lien',
#  '@francoisastorg',
#  '@GCHAlliance',
#  '@lemondefr',
#  '@abr_yann',
#  '@LiberteWatts',
#  '@AMDucroux1',
#  '@sergemartin4',
#  '@AlphalexInform1',
#  '@Calnos1',
#  '@lapin47',
#  '@frededlens',
#  '@LouisdeRedon',
#  '@dracobis',
#  '@Karl_Chretien',
#  '@C3RD4',
#  '@clemrenard_',
#  '@BaudJeana',
#  '@Loic_Ferrieu',
#  '@KTPLeGallois',
#  '@Prefet38',
#  '@harmonie_okg',
#  '@VMatillon',
#  '@falfaled',
#  '@LPhilosophique',
#  '@MUSICBIZ_media',
#  '@NadegeG64',
#  '@cathy09792112',
#  '@nertenliceoff',
#  '@VincentDrezet',
#  '@Panda31808732',
#  '@dstesjules',
#  '@LaVieEnWeb',
#  '@Challenges',
#  '@AutoPlusMag',
#  '@mariongaudin',
#  '@WhitecastleD',
#  '@belou03',
#  '@DavidVo74820499',
#  '@Laforet_Lyon4',
#  '@timeoutparis',
#  '@tomlaigle',
#  '@Cardienec',
#  '@Axel_Darut',
#  '@B2Bolo',
#  '@EFFICYCLE_fr',
#  '@laureldenantes',
#  '@LaPiraterieBack',
#  '@ThomasChappuis',
#  '@fabio35590',
#  '@LaSamaritaine12',
#  '@benjvanpet',
#  '@bernard_volk',
#  '@Bdelor1054',
#  '@StanMendy',
#  '@stephrider',
#  '@Elysee__2022',
#  '@neilmakaroff',
#  '@sretailleau',
#  '@AndreMARTIN126',
#  '@Gaston85105542',
#  '@MonLhuillier',
#  '@Pauline_ANEPF',
#  '@grandin_laurent',
#  '@LaRepDpyrenees',
#  '@RenouveauBxM',
#  '@VirginieDrapier',
#  '@Martine7lnwb',
#  '@cegepduvieuxmtl',
#  '@arefsalem',
#  '@bbel34',
#  '@titrespresse',
#  '@domi_1703',
#  '@franckstassi',
#  '@matheomanon',
#  '@lagrossefouine1',
#  '@LiegeChene',
#  '@FabriceLo',
#  '@4aout',
#  '@MohamadParis20',
#  '@Cevennes75',
#  '@le_Parisien',
#  '@Herve_Bailly_Fr',
#  '@enisseo',
#  '@Axlndsoft',
#  '@boenbot',
#  '@SamiraDIRAT',
#  '@stephaneledez',
#  '@Julietteetienn5',
#  '@reseau_internat',
#  '@RN_BFC',
#  '@GerardDupin',
#  '@Reporterre',
#  '@guigui30000',
#  '@QuimperleVille',
#  '@IsegoriaNantes',
#  '@christianVASSE',
#  '@mauricedelorme3',
#  '@_Bens_M',
#  '@TWLorz',
#  '@GouletNathalie',
#  '@Robin_Salecroix',
#  '@HeleneCruyp',
#  '@cashinvestigati',
#  '@seb92800',
#  '@oxfamfrance',
#  '@ConseilPauvrete',
#  '@enilordnA',
#  '@clauderenard777',
#  '@villedegrigny91',
#  '@Mad_Margaux',
#  '@Grain2Vie',
#  '@Contexte',
#  '@glassofschotch',
#  '@the30man',
#  '@AurelieCoudouel',
#  '@zersinan1',
#  '@Theo_Parigo',
#  '@philippe_ratto',
#  '@Conservateur20',
#  '@rigaud_laurent',
#  '@JMaStarforever',
#  '@francoispinche1',
#  '@FLallemant',
#  '@Prefet976',
#  '@Pierre_Labbe_',
#  '@AOC1978',
#  '@TheDarkPixel',
#  '@melahalk',
#  '@REQMontreal',
#  '@midy_paul',
#  '@littlebigfred',
#  '@templie40351919',
#  '@jbgagnoux',
#  '@AudreyPulvar',
#  '@ChristopheHuy',
#  '@PhdConseils',
#  '@infernale95',
#  '@duodecimal_',
#  '@Chricie29',
#  '@lily_ANESTAPS',
#  '@RevPermanente',
#  '@CabinetExium',
#  '@alpazur_audit',
#  '@Mme_Hall',
#  '@ro2consult',
#  '@NadineLevratto',
#  '@AudaceGaming',
#  '@ArchiMalakoff',
#  '@RICHARDpatrick_',
#  '@SceauxEnsemble',
#  '@pierrehman',
#  '@MyTransitParis',
#  '@Dunkerwest',
#  '@ClintGrease',
#  '@Prefet78',
#  '@bouleber',
#  '@Ephemerenuit',
#  '@zario58',
#  '@Vitopirate',
#  '@libdemnightmare',
#  '@cofinaudit',
#  '@MDelafosse',
#  '@PaulH_B',
#  '@LinucheB',
#  '@PharaonChambers',
#  '@adriendelacroix',
#  '@AngersOnline',
#  '@CorwinAmbre92',
#  '@thinkaboutFR',
#  '@BPartisans',
#  '@SkySpace1865',
#  '@en_psy',
#  '@Iauradee',
#  '@ffunivers',
#  '@DNArchi',
#  '@nathalieappere',
#  '@BabinetCharles',
#  '@LeBreto05734837',
#  '@petimiti',
#  '@PressPepper',
#  '@framaka',
#  '@Fulkymco',
#  '@RouillonJeremy',
#  '@Wandrille_',
#  '@jccm_mtl',
#  '@BessouDaw',
#  '@Paris_OnMyWay',
#  '@peertube_stream',
#  '@Departement19',
#  '@MAYERJeanLoui10',
#  '@Capo_Canellas',
#  '@HadrienDemeure',
#  '@Tour_Insee_IN_C',
#  '@ORU_fr',
#  '@noschlafen',
#  '@zeb2twit',
#  '@nouvelles2025',
#  '@AntoineDireKing',
#  '@feedpushr',
#  '@fontaine_78',
#  '@johannol',
#  '@MarroncleA',
#  '@F_Bouvard_REV',
#  '@Valou_CVA',
#  '@yannchaillou',
#  '@MediabaskInfo',
#  '@jamaislu',
#  '@TdeChassey',
#  '@ANABF5',
#  '@ventdesmaires',
#  '@IsaMadesclaire',
#  '@ChristianDomine',
#  '@libe',
#  '@tahiti_m',
#  '@Johanalyse',
#  '@ElusGsRennes',
#  '@AEffondrement',
#  '@FabioPerruchet',
#  '@mairievitry',
#  '@MauriceCasna',
#  '@Yessine_FAGE',
#  '@eluEs_ACLT',
#  '@DijonMetropole_',
#  '@LaBourseEtLaVie',
#  '@GBatiot',
#  '@maxencedelardus',
#  '@GenErasmus22',
#  '@claudeval',
#  '@Haiemagiqueorg',
#  '@eloitp33',
#  '@QCirculaire',
#  '@MissileV2',
#  '@MarieLaureDavy',
#  '@entpe',
#  '@oddtvlive',
#  '@BArtisanal',
#  '@FlashTweet',
#  '@LaurentESQUENET',
#  '@DoleVeronique',
#  '@fxaimelecantal',
#  '@Erispo3',
#  '@ArgoAvocats',
#  '@credipro92',
#  '@Todomodo55',
#  '@AgicomEC',
#  '@aga_o_bourdon',
#  '@BorisVallaud',
#  '@francois_granet',
#  '@fcauchi',
#  '@Prefet68',
#  '@tduverger',
#  '@SL_Rouillon',
#  '@CedricRathier',
#  '@RenaissanceUE13',
#  '@EssahliAndre',
#  '@TheCityInGames',
#  '@boubou_super',
#  '@kuma_jima',
#  '@jntronc',
#  '@PE_Picard',
#  '@Sichalain',
#  '@ExceliaGroup',
#  '@LontermeE',
#  '@Tourisme_Infos_',
#  '@AdrExpertise',
#  '@CPdauphine',
#  '@HautbourgC',
#  '@DebaesS',
#  '@AssoAeT',
#  '@jl_milliat',
#  '@CRoumegue',
#  '@DavidKonopnicki',
#  '@Emesve',
#  '@InstitutEDS',
#  '@maniglierp',
#  '@LenergieEQ',
#  '@douchink',
#  '@VirginieGuerin2',
#  '@MutMutandis',
#  '@JCDessanges',
#  '@HorizonsBreizh',
#  '@F3Centre',
#  '@Tucciii',
#  '@collectifHBM',
#  '@mairie6_8',
#  '@MathiasCadot',
#  '@EricPainTeamsun',
#  '@Mea_Gouv',
#  '@TRANSITIONVEGE1',
#  '@BancsPublics7',
#  '@cyrilpasteau',
#  '@Pascal15106',
#  '@Vander7535',
#  '@clo_gk',
#  '@laurent_hamon',
#  '@Ally_said_no',
#  '@audreyaronica',
#  '@equiterre',
#  '@mzouareg',
#  '@AgroQuebec',
#  '@shneederfort',
#  '@Indep_Senat',
#  '@villedemarcq',
#  '@Entrepreneurs',
#  '@AbcComptabilite',
#  '@DBangala',
#  '@LyonDecideurs',
#  '@science_md',
#  '@PropreSenegal',
#  '@AugustinCps',
#  '@edstertwit76',
#  '@Tian_A1',
#  '@LInforme_',
#  '@c_vollaire',
#  '@AuxComtesse',
#  '@vickyleandre',
#  '@QCpourTrump',
#  '@LePoint',
#  '@EtienneDemur',
#  '@AsterTKi',
#  '@louismoulin',
#  '@ladepeche09',
#  '@greenpeacefr',
#  '@Waelieu',
#  '@11emeArt',
#  '@BobCavalier',
#  '@RIVIEREBenot1',
#  '@artcile',
#  '@CourrierPicard',
#  '@damien_casse',
#  '@JusticeSocial10',
#  '@zorah_lille',
#  '@PfeifferCarl',
#  '@OuestFrance',
#  '@denisvannier',
#  '@StepanYvan',
#  '@godet_jeremie',
#  '@SevMma',
#  '@FrancisUNDP',
#  '@Aurelientache',
#  '@QuotaClimat',
#  '@SUD_TELEVISION',
#  '@BdT_AntGuyane',
#  '@cgamartinique',
#  '@Figaro_Economie',
#  '@AssoVracParis',
#  '@AperoMedias',
#  '@CourtageSve',
#  '@mayaloola2',
#  '@EricNeumar',
#  '@24sante_fr',
#  '@valie57',
#  '@DumasMichel15',
#  '@TF1Info',
#  '@Prefet27',
#  '@madiya_dorothee',
#  '@MoniaBarkat',
#  '@vidjinnangniG',
#  '@FrancegazAURA',
#  '@AminBrimou',
#  '@PFRunner',
#  '@Amoklaufer',
#  '@TelegrammeGGP',
#  '@fidaltys',
#  '@AzzazNadege',
#  '@BonnevayRemy',
#  '@YoshYosh59',
#  '@ollybret',
#  '@ASSURANCESMEYER',
#  '@ID_LinfoDurable',
#  '@mclucal',
#  '@Castielsewhere',
#  '@Heyjuanito1',
#  '@Loraineroncin',
#  '@JulesWP',
#  '@clement_sas',
#  '@GanArbois',
#  '@al_secco',
#  '@Cabinet_Cogec',
#  '@CX_laurent',
#  '@gan_arriat',
#  '@sebgdu',
#  '@AromaSencha',
#  '@DayanetExperts',
#  '@USBEKetRICA',
#  '@b_etche',
#  '@Assu_Charlet',
#  '@hostilus',
#  '@Le_Figaro',
#  '@Gabrielc6472827',
#  '@DeParfouru',
#  '@DawnyCedric',
#  '@1669770000a',
#  '@AureganYves',
#  '@SaiyanBio',
#  '@Denis_Bapt',
#  '@visant_dessins',
#  '@lionel_thual',
#  '@CouleursParis',
#  '@publicsenat',
#  '@MedefPDL',
#  '@EricBezouSUD',
#  '@alain_co',
#  '@AlexB55170823',
#  '@RmdCoco',
#  '@Mediasinfos',
#  '@TomekTR',
#  '@davidfayon',
#  '@sd2776riseup',
#  '@GuillaumeQ1T1',
#  '@heubeu31',
#  '@MaldororX',
#  '@RMCInfo',
#  '@MALHERBEL',
#  '@MarieMagda6',
#  '@ise_uqam',
#  '@BenjaminBlancBB',
#  '@rougesgorges',
#  '@JN_Gibbs',
#  '@AiretCosmos',
#  '@GChaussemy',
#  '@etdoncalors',
#  '@EmmanuelCapus',
#  '@ming_lilian',
#  '@jeremydumont',
#  '@ClaudeLENGLET',
#  '@NainMangeable',
#  '@sidibemacisse',
#  '@DuteilMyriam',
#  '@gruffat_claude',
#  '@franziska_mnhrz',
#  '@becht_olivier',
#  '@Farida_Amrani_',
#  '@Megoustastou',
#  '@Ecophanie',
#  '@lovizinziair',
#  '@montreal110',
#  '@Emile_Doigts',
#  '@memoristic',
#  '@LAutreCentre',
#  '@MartinezBoloss',
#  '@AsnieresPcf',
#  '@droitdelacom',
#  '@CelsaAlumni',
#  '@la_quile',
#  '@RolandLescure',
#  '@irukanji_invest',
#  '@Gan_Langres',
#  '@mila_moris',
#  '@PascalVerveur',
#  '@SeguretStephane',
#  '@SmartCityFrance',
#  '@kinshasaweb',
#  '@EricLza',
#  '@lindavallee30',
#  '@Orpheus_SM',
#  '@NicolasLoubet',
#  '@mamanufacture',
#  '@vellaviens',
#  '@chomker',
#  '@cgicquel',
#  '@congorassurecd',
#  '@BoujenaO',
#  '@Louvelour',
#  '@MOMOPINUP',
#  '@ramasseudordure',
#  '@antoine_armand',
#  '@YvesBesan',
#  '@Ellikya',
#  '@CNES',
#  '@JeunesG92',
#  '@MVANantes',
#  '@rolandsophie1',
#  '@Foulques44',
#  '@Bapt54',
#  '@benfonty',
#  '@courrierouest',
#  '@BergerieNat',
#  '@ADESAA3',
#  '@valerflore',
#  '@MaMauger',
#  '@LeFigaro_Emploi',
#  '@JR11465512',
#  '@Vi_albu',
#  '@Ecureuil122',
#  '@Liz131975',
#  '@bipx170',
#  '@BBadouard',
#  '@_MaxLoisel',
#  '@LeDuoMalseant',
#  '@jamesinparis',
#  '@GillesDrouin7',
#  '@Laffont4369',
#  '@Intel185',
#  '@ensemble_mvt',
#  '@rodolphe_muller',
#  '@julien_trevisan',
#  '@VJi42532136',
#  '@JuRaLex78',
#  '@RLDI_Lamy',
#  '@ana_anamddk',
#  '@Gaelverchere',
#  '@MedhyDanet',
#  '@sev_anto',
#  '@GGambierThurot',
#  '@RIOCM',
#  '@pierrov',
#  '@Paypalzinor',
#  '@milie_pelletier',
#  '@et_gentil',
#  '@sophie_maze',
#  '@MercierTherese',
#  '@FrancoisRAGE',
#  '@villededivonne',
#  '@LeBivouak',
#  '@ycFreddy',
#  '@EmilieChandler',
#  '@prefetrhone',
#  '@FACE_06',
#  '@daenerys_v076',
#  '@Kendu74',
#  '@TurboDemocrate',
#  '@LehmannDrC',
#  '@Vian_Marc',
#  '@Min_Interieur',
#  '@LucNAROLLES',
#  '@tomroots',
#  '@GazonBreton',
#  '@ajeasso',
#  '@FredericChp',
#  '@PVincourt',
#  '@deinceps',
#  '@bldthomass',
#  '@GourmelonBer',
#  '@Regionsdefrance',
#  '@IThisSaintJean',
#  '@BeurtonLeMignon',
#  '@jc_tortora',
#  '@stanycombat',
#  '@Fabrou13',
#  '@Paula_CSR_SCMP',
#  '@Les_Repliques',
#  '@ca_hurstel',
#  '@souhi999',
#  '@Voirvert',
#  '@FredericMerand',
#  '@Valzen10',
#  '@leJDD',
#  '@nonlgv33',
#  '@ChatCheshire42',
#  '@HeightsLola',
#  '@LLafreux',
#  '@NathanGuedj_',
#  '@GregToulous1',
#  '@CecileGallien',
#  '@MarieHbib',
#  '@Lauwette77',
#  '@AgroChimie',
#  '@Jdbouk1',
#  '@EmilieGaub',
#  '@_Akanoa_',
#  '@lachape_one',
#  '@Mahamat_25',
#  '@Mouettedelouest',
#  '@CheminotsCgt',
#  '@ghjattu_neru',
#  '@nfroidure',
#  '@CarroueYves',
#  '@ecoleau',
#  '@JohnBikeLane',
#  '@matthieuriff',
#  '@ahaoups',
#  '@LCP',
#  '@KerbratVivien',
#  '@arthur_skr',
#  '@BayaCiamala',
#  '@denisfabre',
#  '@cTmieuxJadis',
#  '@shellyj25178398',
#  '@GabrielAttal',
#  '@Juste2T',
#  '@Mobisphere',
#  '@sauvonsleclimat',
#  '@Haute43',
#  '@PierreJeanMaure',
#  '@DinaKoussou',
#  '@mtrauchessec',
#  '@Solenat_',
#  '@rouxad27',
#  '@actu_IA_Monde',
#  '@AxeVertRamee',
#  '@CaroitEleonore',
#  '@no1xbt_',
#  '@ControleurPM733',
#  '@jeremycamus',
#  '@HiceoFr',
#  '@bfmbusiness',
#  '@techandco',
#  '@pagachey',
#  '@FRANCOIS8139',
#  '@BCouillard33',
#  '@edastarac',
#  '@JTroccaz',
#  '@JourdainMartin',
#  '@BylyCjo7',
#  '@BOUKHARIThierry',
#  '@tristanwaleckx',
#  '@le_maulf',
#  '@InfoFlash_44',
#  '@intwittoveritas',
#  '@VRM_ca',
#  '@ALpinino_',
#  '@08Estelle06D10',
#  '@Draanek_tv',
#  '@OrsonDidier',
#  '@PIERREERREIP3',
#  '@mocgab',
#  '@Var_Matin',
#  '@daniele_noel',
#  '@Horizons_SB22',
#  '@climat_urbain',
#  '@alternatiba75',
#  '@Renaissance_d22',
#  '@ingecube_',
#  '@bob2m80',
#  '@tdldp',
#  '@kalonbuntu33',
#  '@BaixSegura_es',
#  '@FabienCazenave',
#  '@lamarsweb',
#  '@ChrisLenabour',
#  '@RauxJF',
#  '@MbulukuMoise',
#  '@MilhommeO',
#  '@sartout',
#  '@bisdeclugny',
#  '@LCFPVPecresse',
#  '@SergeGrouard',
#  '@TMaugier',
#  '@boris_ravignon',
#  '@YannWehrling',
#  '@Rudboy83',
#  '@PtiteRepublique',
#  '@J_Bardella',
#  '@Bosco_974',
#  '@CapitaineFlam14',
#  '@lotcharlot',
#  '@Rubson28247850',
#  '@vollesprit',
#  '@MichaelMrtl',
#  '@Max_Tech_42',
#  '@VSoille',
#  '@Lacourt05602281',
#  '@jibhey',
#  '@ca_ginesy',
#  '@LxP1210',
#  '@adovox',
#  '@P1erreLagrange',
#  '@CiteDesChances',
#  '@gauchopathe',
#  '@EagisCorp',
#  '@albiaanews',
#  '@33AC64',
#  '@GrenierJeanBap2',
#  '@Jnb311',
#  '@Citoyen83674311',
#  '@whispershoutlow',
#  '@SebPoGo',
#  '@franceinfo',
#  '@AureliAssouline',
#  '@hertzeleid',
#  '@sduhamel357',
#  '@leditiondusoir',
#  '@MEUSEFM',
#  '@StFeMarseille',
#  '@Poerava17916088',
#  '@Philoufish44',
#  '@asdl44',
#  ...]

# %%
# Vérifie si le premier caractère est un @ et le supprime, sinon garde l'ID
dict_acteurs_unique = [
    char[1:] if char.startswith('@')
    else char for char in dict_acteurs_unique
]

# %%
dict_acteurs_unique
# Out:
# ['PaysagesIroise',
#  'InfosEducation',
#  'VIENSflashmober',
#  'LIBERTE1311',
#  'PACOLLOT',
#  'verolive83',
#  'Hergastul',
#  'PatrickGlesener',
#  'giOrdanoB6946',
#  'randomie7i',
#  'Marie08979035',
#  'JeannotMbaya',
#  'latulipenoire31',
#  'Olivancalderone',
#  'MySweetimmo',
#  'LaurencePalais',
#  'PMonoxyle',
#  'MendiniNassim',
#  'DavidBorie4',
#  'BARLANicolas1',
#  'Ortofon76',
#  'Prefet49',
#  'sophie_bussiere',
#  'lemainelibre',
#  'Actuenviro',
#  'AudreyHenocque',
#  'eco_actu',
#  'SartheInfos',
#  'groum_groum',
#  'Babapolitique',
#  'Q_deBremond',
#  'RomainLaveau',
#  'FrexitOtanExit',
#  'Cesarmand',
#  'o_environnement',
#  'LaTribune',
#  'LCI',
#  'imperma1914',
#  'ChristopheBechu',
#  'FredBesnard',
#  'Trunkhanwow',
#  'UnivDroit_EDD',
#  'TLConseil',
#  'favier_florent',
#  'deslnfor',
#  'Benjam1Lucas',
#  'shilderi',
#  'Vivien_PI',
#  'DorianBianco07',
#  'LouisLghni',
#  'Lejeune_paris',
#  'communiquaction',
#  'FrancoisBulloc1',
#  'jeremyerline',
#  'EadgGdea',
#  'FabriceRivet',
#  'SachaMaunier',
#  'JuliaCerisi',
#  'melggo',
#  'iwona46',
#  'ChaBahuon',
#  'antoinecaplan',
#  'HachaniNaima',
#  'm_Romagnani',
#  'LibertyLoveFr',
#  'reix_toine',
#  'JeunesseNupes',
#  'Antoine0667Best',
#  'Arr_Verdun',
#  'DarkPhoenix9666',
#  'LP641',
#  'jnbarrot',
#  'RDelinfo',
#  'NoamLeandri',
#  'benoitbonte',
#  'VeloBucVGP',
#  'VonbraunWerner',
#  'Firenault',
#  'claran55',
#  'Goulran_',
#  'baceau',
#  'ademe',
#  'ChristVdbPro',
#  'Madininair972',
#  'systemcruyff',
#  'escaledenuit',
#  'Jean_LucFUGIT',
#  '24matins',
#  'Pour_Gagner_35',
#  'jacquesantoine',
#  'X345__',
#  'ElisabethLavill',
#  'lemonde_campus',
#  'AirMilarsky',
#  'JeanPierreDESHA',
#  'MetropoliticBot',
#  'MyriamVillert',
#  'luccarvounas',
#  'Renaud_83990',
#  'auvergne_infos',
#  'HenryM_63',
#  'a_leboeuf',
#  'DavidLegros33',
#  'andreaxlubeck',
#  'Vincent48557733',
#  'Valiryus',
#  'villedemougins',
#  'vinougradus',
#  'FoncelJerome',
#  'IPSL_outreach',
#  'NicolNogent',
#  'BELLATFoot',
#  'baffeur77',
#  'BoudPrototype',
#  'MasterCEDDETE',
#  'mpatrick21',
#  'F3PaysdelaLoire',
#  'adsaum',
#  'Noelherve5',
#  'CabinetAgcr',
#  'MargauxVIDAL1',
#  'XhiphiasG',
#  'ville_chaville',
#  'RicolotContact',
#  'Befalimpertinen',
#  'Cdanslair',
#  'MarcoMonigaAtos',
#  'FlorenceBlatrix',
#  'TPoulinier',
#  'JouveauM',
#  'AxThV',
#  'jchapuis',
#  'FNAIM_Picardie',
#  'Infos_Dijon',
#  'ze_flower',
#  'michelsalion',
#  'Pasunmouton2',
#  'stanley_kub',
#  'Mr_Zakka',
#  'BSR_Associes',
#  'Boiscom',
#  'MarieCasan',
#  'sterdyniak',
#  'ColineSomek',
#  'JulienGossa',
#  'Pandalatesta',
#  'RomannKer',
#  'franceEcoMag',
#  'Hemail_79',
#  'LaurentAlfonso',
#  'ArnCollignon',
#  'lesradicaux_',
#  '365jeuxenfamil1',
#  'rlarvent',
#  'rococo321',
#  'dlbrgn',
#  'cci_ardennes',
#  'dominique_meda',
#  'SophieBellon',
#  'frlinget',
#  'jedy00075',
#  'fdecoster',
#  'gyrovaguerie',
#  'PierreCazeneuve',
#  'EricSartori3',
#  'jmvittori',
#  'RE_RueilMalmais',
#  'geholf',
#  'atterres',
#  'PhilippeBUERCH',
#  'GIRcontact',
#  'BusinessBourse',
#  'AnneMarieJean1',
#  'JaneOfArc6',
#  'eelvParis10',
#  'jamy_william',
#  '7Milx1',
#  'JCEV15',
#  'LaurePressac',
#  'LDinclaux',
#  'RL_Patriote',
#  'ArnaudAbel',
#  'GregIenco',
#  'PatDucratin',
#  'greenvincent',
#  'RobyAgathe',
#  'Nikki_Sane',
#  'Solange__C',
#  'Departement_971',
#  'presseocean',
#  'YoussefDoghmane',
#  'JadoreMontreal',
#  'PiNetworkFrance',
#  'clesdusocial',
#  'amandine_ynwa',
#  'Maxime92160',
#  'EcoloParis19',
#  'lailatov',
#  'MHAmiable',
#  'JohnMitchell4x8',
#  'Mikaa_H2',
#  'FuriousKoen',
#  'rosemarie4710',
#  'ulyssedorioz',
#  'IamEntry',
#  'JM_Verchere',
#  'laurentdejoie',
#  'EyquemLeonard',
#  'StanGuerini',
#  'Mobrooo',
#  'ManciniIsabelle',
#  'marcgrosman75',
#  'FindinLanguedoc',
#  'S_Revages',
#  'SebStanBono',
#  'LeDL737401',
#  'ademe_bretagne',
#  'NicolasKlatka',
#  'flyCSI',
#  'pabouger',
#  'Spike2577',
#  'JeremieLandreau',
#  'RaynaldBernier',
#  'CabinetGsell',
#  'FdeRugy',
#  'FairPlay4Planet',
#  'MartinFierro769',
#  'Ecoyako_',
#  'phenixfr',
#  'SimpleF12656939',
#  'ATokenInvestor',
#  'nave_va',
#  'BenjaminTeoule',
#  'AdriendeVlt',
#  'ch_lemercier',
#  'MoukouB',
#  'Melenchon4Ever',
#  'CecileVignesM',
#  'Lacjoe1',
#  'ecoleiet',
#  'vincent_monot',
#  'PHD442',
#  'GHClamart',
#  'FabienneGrebert',
#  'leparisien2024',
#  'lp_materre',
#  'DeremeAvocat',
#  'KimKimuntu',
#  'pascal_mulegwa',
#  'acprdc_Officiel',
#  'Linossier7',
#  'meteo60',
#  'Lamasticot__',
#  'haricotsbleus',
#  'RaymondBykouko',
#  'aeros_wing',
#  'franckcourchamp',
#  'Victor_obrt',
#  'laulecoeur',
#  'anne_sicard',
#  'lau68951920',
#  'Stonks_Corp',
#  'TabouleAAAAAAAH',
#  'matgautier',
#  'LucasPetit92',
#  'homocommuniste',
#  'voxjaen',
#  'LEPETITSteph',
#  'ChMerchadou',
#  'LoucasPinto1',
#  'vinzradio',
#  'kevCi3',
#  'fnadac',
#  'PatrickMonin71',
#  'ABPtwit',
#  'Eleazar_jd',
#  'ThomasL18174027',
#  'Cmo351',
#  'fred_mrs',
#  'chateau_gontier',
#  'matzenox',
#  'DudesertFred',
#  'CRECQ',
#  'GregRoquett',
#  'AlexisJanicot',
#  'dm_petit',
#  'Canope_40',
#  'VRwatchingU',
#  'TanShanLiMTL',
#  'chanezherbanne',
#  'sophiepiard',
#  'HugCharbonneau',
#  'Burlesque_32',
#  'EmmanFernandes',
#  'didjule',
#  'VilledeChenove',
#  'ChloeClair_namR',
#  'Izidra_',
#  'danlert',
#  'VicGranier',
#  'Ccesoir',
#  'tcoiffeurjustes',
#  'ChrisLavaquerie',
#  'AnneTallineau',
#  'SoniaBEKO',
#  'HMassenet',
#  'corsenetinfos',
#  'EricKrezel',
#  'GreenpeaceTours',
#  'RANCHEREP',
#  'lepenenchon',
#  'SalifKO31547825',
#  'WelterDelphine',
#  'lowtechs',
#  'TransitionsEco',
#  'netguide',
#  'FP_Champagne',
#  'RV_Joly',
#  'MajidZiraoui',
#  'B_SMART_TV',
#  'nutriac',
#  'aure79lien',
#  'francoisastorg',
#  'GCHAlliance',
#  'lemondefr',
#  'abr_yann',
#  'LiberteWatts',
#  'AMDucroux1',
#  'sergemartin4',
#  'AlphalexInform1',
#  'Calnos1',
#  'lapin47',
#  'frededlens',
#  'LouisdeRedon',
#  'dracobis',
#  'Karl_Chretien',
#  'C3RD4',
#  'clemrenard_',
#  'BaudJeana',
#  'Loic_Ferrieu',
#  'KTPLeGallois',
#  'Prefet38',
#  'harmonie_okg',
#  'VMatillon',
#  'falfaled',
#  'LPhilosophique',
#  'MUSICBIZ_media',
#  'NadegeG64',
#  'cathy09792112',
#  'nertenliceoff',
#  'VincentDrezet',
#  'Panda31808732',
#  'dstesjules',
#  'LaVieEnWeb',
#  'Challenges',
#  'AutoPlusMag',
#  'mariongaudin',
#  'WhitecastleD',
#  'belou03',
#  'DavidVo74820499',
#  'Laforet_Lyon4',
#  'timeoutparis',
#  'tomlaigle',
#  'Cardienec',
#  'Axel_Darut',
#  'B2Bolo',
#  'EFFICYCLE_fr',
#  'laureldenantes',
#  'LaPiraterieBack',
#  'ThomasChappuis',
#  'fabio35590',
#  'LaSamaritaine12',
#  'benjvanpet',
#  'bernard_volk',
#  'Bdelor1054',
#  'StanMendy',
#  'stephrider',
#  'Elysee__2022',
#  'neilmakaroff',
#  'sretailleau',
#  'AndreMARTIN126',
#  'Gaston85105542',
#  'MonLhuillier',
#  'Pauline_ANEPF',
#  'grandin_laurent',
#  'LaRepDpyrenees',
#  'RenouveauBxM',
#  'VirginieDrapier',
#  'Martine7lnwb',
#  'cegepduvieuxmtl',
#  'arefsalem',
#  'bbel34',
#  'titrespresse',
#  'domi_1703',
#  'franckstassi',
#  'matheomanon',
#  'lagrossefouine1',
#  'LiegeChene',
#  'FabriceLo',
#  '4aout',
#  'MohamadParis20',
#  'Cevennes75',
#  'le_Parisien',
#  'Herve_Bailly_Fr',
#  'enisseo',
#  'Axlndsoft',
#  'boenbot',
#  'SamiraDIRAT',
#  'stephaneledez',
#  'Julietteetienn5',
#  'reseau_internat',
#  'RN_BFC',
#  'GerardDupin',
#  'Reporterre',
#  'guigui30000',
#  'QuimperleVille',
#  'IsegoriaNantes',
#  'christianVASSE',
#  'mauricedelorme3',
#  '_Bens_M',
#  'TWLorz',
#  'GouletNathalie',
#  'Robin_Salecroix',
#  'HeleneCruyp',
#  'cashinvestigati',
#  'seb92800',
#  'oxfamfrance',
#  'ConseilPauvrete',
#  'enilordnA',
#  'clauderenard777',
#  'villedegrigny91',
#  'Mad_Margaux',
#  'Grain2Vie',
#  'Contexte',
#  'glassofschotch',
#  'the30man',
#  'AurelieCoudouel',
#  'zersinan1',
#  'Theo_Parigo',
#  'philippe_ratto',
#  'Conservateur20',
#  'rigaud_laurent',
#  'JMaStarforever',
#  'francoispinche1',
#  'FLallemant',
#  'Prefet976',
#  'Pierre_Labbe_',
#  'AOC1978',
#  'TheDarkPixel',
#  'melahalk',
#  'REQMontreal',
#  'midy_paul',
#  'littlebigfred',
#  'templie40351919',
#  'jbgagnoux',
#  'AudreyPulvar',
#  'ChristopheHuy',
#  'PhdConseils',
#  'infernale95',
#  'duodecimal_',
#  'Chricie29',
#  'lily_ANESTAPS',
#  'RevPermanente',
#  'CabinetExium',
#  'alpazur_audit',
#  'Mme_Hall',
#  'ro2consult',
#  'NadineLevratto',
#  'AudaceGaming',
#  'ArchiMalakoff',
#  'RICHARDpatrick_',
#  'SceauxEnsemble',
#  'pierrehman',
#  'MyTransitParis',
#  'Dunkerwest',
#  'ClintGrease',
#  'Prefet78',
#  'bouleber',
#  'Ephemerenuit',
#  'zario58',
#  'Vitopirate',
#  'libdemnightmare',
#  'cofinaudit',
#  'MDelafosse',
#  'PaulH_B',
#  'LinucheB',
#  'PharaonChambers',
#  'adriendelacroix',
#  'AngersOnline',
#  'CorwinAmbre92',
#  'thinkaboutFR',
#  'BPartisans',
#  'SkySpace1865',
#  'en_psy',
#  'Iauradee',
#  'ffunivers',
#  'DNArchi',
#  'nathalieappere',
#  'BabinetCharles',
#  'LeBreto05734837',
#  'petimiti',
#  'PressPepper',
#  'framaka',
#  'Fulkymco',
#  'RouillonJeremy',
#  'Wandrille_',
#  'jccm_mtl',
#  'BessouDaw',
#  'Paris_OnMyWay',
#  'peertube_stream',
#  'Departement19',
#  'MAYERJeanLoui10',
#  'Capo_Canellas',
#  'HadrienDemeure',
#  'Tour_Insee_IN_C',
#  'ORU_fr',
#  'noschlafen',
#  'zeb2twit',
#  'nouvelles2025',
#  'AntoineDireKing',
#  'feedpushr',
#  'fontaine_78',
#  'johannol',
#  'MarroncleA',
#  'F_Bouvard_REV',
#  'Valou_CVA',
#  'yannchaillou',
#  'MediabaskInfo',
#  'jamaislu',
#  'TdeChassey',
#  'ANABF5',
#  'ventdesmaires',
#  'IsaMadesclaire',
#  'ChristianDomine',
#  'libe',
#  'tahiti_m',
#  'Johanalyse',
#  'ElusGsRennes',
#  'AEffondrement',
#  'FabioPerruchet',
#  'mairievitry',
#  'MauriceCasna',
#  'Yessine_FAGE',
#  'eluEs_ACLT',
#  'DijonMetropole_',
#  'LaBourseEtLaVie',
#  'GBatiot',
#  'maxencedelardus',
#  'GenErasmus22',
#  'claudeval',
#  'Haiemagiqueorg',
#  'eloitp33',
#  'QCirculaire',
#  'MissileV2',
#  'MarieLaureDavy',
#  'entpe',
#  'oddtvlive',
#  'BArtisanal',
#  'FlashTweet',
#  'LaurentESQUENET',
#  'DoleVeronique',
#  'fxaimelecantal',
#  'Erispo3',
#  'ArgoAvocats',
#  'credipro92',
#  'Todomodo55',
#  'AgicomEC',
#  'aga_o_bourdon',
#  'BorisVallaud',
#  'francois_granet',
#  'fcauchi',
#  'Prefet68',
#  'tduverger',
#  'SL_Rouillon',
#  'CedricRathier',
#  'RenaissanceUE13',
#  'EssahliAndre',
#  'TheCityInGames',
#  'boubou_super',
#  'kuma_jima',
#  'jntronc',
#  'PE_Picard',
#  'Sichalain',
#  'ExceliaGroup',
#  'LontermeE',
#  'Tourisme_Infos_',
#  'AdrExpertise',
#  'CPdauphine',
#  'HautbourgC',
#  'DebaesS',
#  'AssoAeT',
#  'jl_milliat',
#  'CRoumegue',
#  'DavidKonopnicki',
#  'Emesve',
#  'InstitutEDS',
#  'maniglierp',
#  'LenergieEQ',
#  'douchink',
#  'VirginieGuerin2',
#  'MutMutandis',
#  'JCDessanges',
#  'HorizonsBreizh',
#  'F3Centre',
#  'Tucciii',
#  'collectifHBM',
#  'mairie6_8',
#  'MathiasCadot',
#  'EricPainTeamsun',
#  'Mea_Gouv',
#  'TRANSITIONVEGE1',
#  'BancsPublics7',
#  'cyrilpasteau',
#  'Pascal15106',
#  'Vander7535',
#  'clo_gk',
#  'laurent_hamon',
#  'Ally_said_no',
#  'audreyaronica',
#  'equiterre',
#  'mzouareg',
#  'AgroQuebec',
#  'shneederfort',
#  'Indep_Senat',
#  'villedemarcq',
#  'Entrepreneurs',
#  'AbcComptabilite',
#  'DBangala',
#  'LyonDecideurs',
#  'science_md',
#  'PropreSenegal',
#  'AugustinCps',
#  'edstertwit76',
#  'Tian_A1',
#  'LInforme_',
#  'c_vollaire',
#  'AuxComtesse',
#  'vickyleandre',
#  'QCpourTrump',
#  'LePoint',
#  'EtienneDemur',
#  'AsterTKi',
#  'louismoulin',
#  'ladepeche09',
#  'greenpeacefr',
#  'Waelieu',
#  '11emeArt',
#  'BobCavalier',
#  'RIVIEREBenot1',
#  'artcile',
#  'CourrierPicard',
#  'damien_casse',
#  'JusticeSocial10',
#  'zorah_lille',
#  'PfeifferCarl',
#  'OuestFrance',
#  'denisvannier',
#  'StepanYvan',
#  'godet_jeremie',
#  'SevMma',
#  'FrancisUNDP',
#  'Aurelientache',
#  'QuotaClimat',
#  'SUD_TELEVISION',
#  'BdT_AntGuyane',
#  'cgamartinique',
#  'Figaro_Economie',
#  'AssoVracParis',
#  'AperoMedias',
#  'CourtageSve',
#  'mayaloola2',
#  'EricNeumar',
#  '24sante_fr',
#  'valie57',
#  'DumasMichel15',
#  'TF1Info',
#  'Prefet27',
#  'madiya_dorothee',
#  'MoniaBarkat',
#  'vidjinnangniG',
#  'FrancegazAURA',
#  'AminBrimou',
#  'PFRunner',
#  'Amoklaufer',
#  'TelegrammeGGP',
#  'fidaltys',
#  'AzzazNadege',
#  'BonnevayRemy',
#  'YoshYosh59',
#  'ollybret',
#  'ASSURANCESMEYER',
#  'ID_LinfoDurable',
#  'mclucal',
#  'Castielsewhere',
#  'Heyjuanito1',
#  'Loraineroncin',
#  'JulesWP',
#  'clement_sas',
#  'GanArbois',
#  'al_secco',
#  'Cabinet_Cogec',
#  'CX_laurent',
#  'gan_arriat',
#  'sebgdu',
#  'AromaSencha',
#  'DayanetExperts',
#  'USBEKetRICA',
#  'b_etche',
#  'Assu_Charlet',
#  'hostilus',
#  'Le_Figaro',
#  'Gabrielc6472827',
#  'DeParfouru',
#  'DawnyCedric',
#  '1669770000a',
#  'AureganYves',
#  'SaiyanBio',
#  'Denis_Bapt',
#  'visant_dessins',
#  'lionel_thual',
#  'CouleursParis',
#  'publicsenat',
#  'MedefPDL',
#  'EricBezouSUD',
#  'alain_co',
#  'AlexB55170823',
#  'RmdCoco',
#  'Mediasinfos',
#  'TomekTR',
#  'davidfayon',
#  'sd2776riseup',
#  'GuillaumeQ1T1',
#  'heubeu31',
#  'MaldororX',
#  'RMCInfo',
#  'MALHERBEL',
#  'MarieMagda6',
#  'ise_uqam',
#  'BenjaminBlancBB',
#  'rougesgorges',
#  'JN_Gibbs',
#  'AiretCosmos',
#  'GChaussemy',
#  'etdoncalors',
#  'EmmanuelCapus',
#  'ming_lilian',
#  'jeremydumont',
#  'ClaudeLENGLET',
#  'NainMangeable',
#  'sidibemacisse',
#  'DuteilMyriam',
#  'gruffat_claude',
#  'franziska_mnhrz',
#  'becht_olivier',
#  'Farida_Amrani_',
#  'Megoustastou',
#  'Ecophanie',
#  'lovizinziair',
#  'montreal110',
#  'Emile_Doigts',
#  'memoristic',
#  'LAutreCentre',
#  'MartinezBoloss',
#  'AsnieresPcf',
#  'droitdelacom',
#  'CelsaAlumni',
#  'la_quile',
#  'RolandLescure',
#  'irukanji_invest',
#  'Gan_Langres',
#  'mila_moris',
#  'PascalVerveur',
#  'SeguretStephane',
#  'SmartCityFrance',
#  'kinshasaweb',
#  'EricLza',
#  'lindavallee30',
#  'Orpheus_SM',
#  'NicolasLoubet',
#  'mamanufacture',
#  'vellaviens',
#  'chomker',
#  'cgicquel',
#  'congorassurecd',
#  'BoujenaO',
#  'Louvelour',
#  'MOMOPINUP',
#  'ramasseudordure',
#  'antoine_armand',
#  'YvesBesan',
#  'Ellikya',
#  'CNES',
#  'JeunesG92',
#  'MVANantes',
#  'rolandsophie1',
#  'Foulques44',
#  'Bapt54',
#  'benfonty',
#  'courrierouest',
#  'BergerieNat',
#  'ADESAA3',
#  'valerflore',
#  'MaMauger',
#  'LeFigaro_Emploi',
#  'JR11465512',
#  'Vi_albu',
#  'Ecureuil122',
#  'Liz131975',
#  'bipx170',
#  'BBadouard',
#  '_MaxLoisel',
#  'LeDuoMalseant',
#  'jamesinparis',
#  'GillesDrouin7',
#  'Laffont4369',
#  'Intel185',
#  'ensemble_mvt',
#  'rodolphe_muller',
#  'julien_trevisan',
#  'VJi42532136',
#  'JuRaLex78',
#  'RLDI_Lamy',
#  'ana_anamddk',
#  'Gaelverchere',
#  'MedhyDanet',
#  'sev_anto',
#  'GGambierThurot',
#  'RIOCM',
#  'pierrov',
#  'Paypalzinor',
#  'milie_pelletier',
#  'et_gentil',
#  'sophie_maze',
#  'MercierTherese',
#  'FrancoisRAGE',
#  'villededivonne',
#  'LeBivouak',
#  'ycFreddy',
#  'EmilieChandler',
#  'prefetrhone',
#  'FACE_06',
#  'daenerys_v076',
#  'Kendu74',
#  'TurboDemocrate',
#  'LehmannDrC',
#  'Vian_Marc',
#  'Min_Interieur',
#  'LucNAROLLES',
#  'tomroots',
#  'GazonBreton',
#  'ajeasso',
#  'FredericChp',
#  'PVincourt',
#  'deinceps',
#  'bldthomass',
#  'GourmelonBer',
#  'Regionsdefrance',
#  'IThisSaintJean',
#  'BeurtonLeMignon',
#  'jc_tortora',
#  'stanycombat',
#  'Fabrou13',
#  'Paula_CSR_SCMP',
#  'Les_Repliques',
#  'ca_hurstel',
#  'souhi999',
#  'Voirvert',
#  'FredericMerand',
#  'Valzen10',
#  'leJDD',
#  'nonlgv33',
#  'ChatCheshire42',
#  'HeightsLola',
#  'LLafreux',
#  'NathanGuedj_',
#  'GregToulous1',
#  'CecileGallien',
#  'MarieHbib',
#  'Lauwette77',
#  'AgroChimie',
#  'Jdbouk1',
#  'EmilieGaub',
#  '_Akanoa_',
#  'lachape_one',
#  'Mahamat_25',
#  'Mouettedelouest',
#  'CheminotsCgt',
#  'ghjattu_neru',
#  'nfroidure',
#  'CarroueYves',
#  'ecoleau',
#  'JohnBikeLane',
#  'matthieuriff',
#  'ahaoups',
#  'LCP',
#  'KerbratVivien',
#  'arthur_skr',
#  'BayaCiamala',
#  'denisfabre',
#  'cTmieuxJadis',
#  'shellyj25178398',
#  'GabrielAttal',
#  'Juste2T',
#  'Mobisphere',
#  'sauvonsleclimat',
#  'Haute43',
#  'PierreJeanMaure',
#  'DinaKoussou',
#  'mtrauchessec',
#  'Solenat_',
#  'rouxad27',
#  'actu_IA_Monde',
#  'AxeVertRamee',
#  'CaroitEleonore',
#  'no1xbt_',
#  'ControleurPM733',
#  'jeremycamus',
#  'HiceoFr',
#  'bfmbusiness',
#  'techandco',
#  'pagachey',
#  'FRANCOIS8139',
#  'BCouillard33',
#  'edastarac',
#  'JTroccaz',
#  'JourdainMartin',
#  'BylyCjo7',
#  'BOUKHARIThierry',
#  'tristanwaleckx',
#  'le_maulf',
#  'InfoFlash_44',
#  'intwittoveritas',
#  'VRM_ca',
#  'ALpinino_',
#  '08Estelle06D10',
#  'Draanek_tv',
#  'OrsonDidier',
#  'PIERREERREIP3',
#  'mocgab',
#  'Var_Matin',
#  'daniele_noel',
#  'Horizons_SB22',
#  'climat_urbain',
#  'alternatiba75',
#  'Renaissance_d22',
#  'ingecube_',
#  'bob2m80',
#  'tdldp',
#  'kalonbuntu33',
#  'BaixSegura_es',
#  'FabienCazenave',
#  'lamarsweb',
#  'ChrisLenabour',
#  'RauxJF',
#  'MbulukuMoise',
#  'MilhommeO',
#  'sartout',
#  'bisdeclugny',
#  'LCFPVPecresse',
#  'SergeGrouard',
#  'TMaugier',
#  'boris_ravignon',
#  'YannWehrling',
#  'Rudboy83',
#  'PtiteRepublique',
#  'J_Bardella',
#  'Bosco_974',
#  'CapitaineFlam14',
#  'lotcharlot',
#  'Rubson28247850',
#  'vollesprit',
#  'MichaelMrtl',
#  'Max_Tech_42',
#  'VSoille',
#  'Lacourt05602281',
#  'jibhey',
#  'ca_ginesy',
#  'LxP1210',
#  'adovox',
#  'P1erreLagrange',
#  'CiteDesChances',
#  'gauchopathe',
#  'EagisCorp',
#  'albiaanews',
#  '33AC64',
#  'GrenierJeanBap2',
#  'Jnb311',
#  'Citoyen83674311',
#  'whispershoutlow',
#  'SebPoGo',
#  'franceinfo',
#  'AureliAssouline',
#  'hertzeleid',
#  'sduhamel357',
#  'leditiondusoir',
#  'MEUSEFM',
#  'StFeMarseille',
#  'Poerava17916088',
#  'Philoufish44',
#  'asdl44',
#  ...]

# %%
#dict_acteurs_unique2 = dict_acteurs_unique[:500]

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup

# %%
# Liste pour stocker les résultats
profile_results = []

# Boucle sur chaque utilisateur
for user_id in dict_acteurs_unique:
    # Construire l'URL du profil de l'utilisateur
    url = f"https://nitter.net/{user_id}"
    
    # Requête HTTP & récupération du contenu de la page (+ ajout d'un header pour contourner la sécurité Nitter)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    req = Request(url, headers=headers)
    response = urlopen(req)
    soup = BeautifulSoup(response.read(), 'html.parser')
    
    # Extraire les informations du profil
    utilisateur_name = soup.find('a', {'class': 'profile-card-fullname'}).text.strip()
    profile_bio_element = soup.find('div', {'class': 'profile-bio'})
    profile_bio = profile_bio_element.text.strip() if profile_bio_element is not None else ""
    tweets_count = soup.find('li', {'class': 'posts'}).find('span', {'class': 'profile-stat-num'}).text.strip()
    following_count = soup.find('li', {'class': 'following'}).find('span', {'class': 'profile-stat-num'}).text.strip()
    followers_count = soup.find('li', {'class': 'followers'}).find('span', {'class': 'profile-stat-num'}).text.strip()
    likes_count = soup.find('li', {'class': 'likes'}).find('span', {'class': 'profile-stat-num'}).text.strip()
    
    # Supprimer les virgules dans les métriques
    tweets_count = tweets_count.replace(",", "")
    following_count = following_count.replace(",", "")
    followers_count = followers_count.replace(",", "")
    likes_count = likes_count.replace(",", "")
    
    # Ajouter les informations du profil à la liste des résultats
    profile_results.append({
        'Utilisateur_id': user_id,
        'Utilisateur_name': utilisateur_name,
        'Profile_bio': profile_bio,
        'Tweets': tweets_count,
        'Following': following_count,
        'Followers': followers_count,
        'Likes': likes_count
    })
    print(user_id)

# Créer un DataFrame à partir des résultats
dict_acteurs_final = pd.DataFrame(profile_results)
# Out:
# PaysagesIroise
# InfosEducation
# VIENSflashmober
# LIBERTE1311
# PACOLLOT
# verolive83
# Hergastul
# PatrickGlesener
# giOrdanoB6946
# randomie7i
# Marie08979035
# JeannotMbaya
# latulipenoire31
# Olivancalderone
# MySweetimmo
# LaurencePalais
# PMonoxyle
# MendiniNassim
# DavidBorie4
# BARLANicolas1
# Ortofon76
# Prefet49
# sophie_bussiere
# lemainelibre
# Actuenviro
# AudreyHenocque
# eco_actu
# SartheInfos
# groum_groum
# Babapolitique
# Q_deBremond
# RomainLaveau
# FrexitOtanExit
# Cesarmand
# o_environnement
# LaTribune
# LCI
# imperma1914
# ChristopheBechu
# FredBesnard
# Trunkhanwow
# UnivDroit_EDD
# TLConseil
# favier_florent
# deslnfor
# Benjam1Lucas
# shilderi
# Vivien_PI
# DorianBianco07
# LouisLghni
# Lejeune_paris
# communiquaction
# FrancoisBulloc1
# jeremyerline
# EadgGdea
# FabriceRivet
# SachaMaunier
# JuliaCerisi
# melggo
# iwona46
# ChaBahuon
# antoinecaplan
# HachaniNaima
# m_Romagnani
# LibertyLoveFr
# reix_toine
# JeunesseNupes
# Antoine0667Best
# Arr_Verdun
# DarkPhoenix9666
# LP641
# jnbarrot
# RDelinfo
# NoamLeandri
# benoitbonte
# VeloBucVGP
# VonbraunWerner
# Firenault
# claran55
# Goulran_
# baceau
# ademe
# ChristVdbPro
# Madininair972
# systemcruyff
# escaledenuit
# Jean_LucFUGIT
# 24matins
# Pour_Gagner_35
# jacquesantoine
# X345__
# ElisabethLavill
# lemonde_campus
# AirMilarsky
# JeanPierreDESHA
# MetropoliticBot
# MyriamVillert
# luccarvounas
# Renaud_83990
# auvergne_infos
# HenryM_63
# a_leboeuf
# DavidLegros33
# andreaxlubeck
# Vincent48557733
# Valiryus
# villedemougins
# vinougradus
# FoncelJerome
# IPSL_outreach
# NicolNogent
# BELLATFoot
# baffeur77
# BoudPrototype
# MasterCEDDETE
# mpatrick21
# F3PaysdelaLoire
# adsaum
# Noelherve5
# CabinetAgcr
# MargauxVIDAL1
# XhiphiasG
# ville_chaville
# RicolotContact
# Befalimpertinen
# Cdanslair
# MarcoMonigaAtos
# FlorenceBlatrix
# TPoulinier
# JouveauM
# AxThV
# jchapuis
# FNAIM_Picardie
# Infos_Dijon
# ze_flower
# michelsalion
# Pasunmouton2
# stanley_kub
# Mr_Zakka
# BSR_Associes
# Boiscom
# MarieCasan
# sterdyniak
# ColineSomek
# JulienGossa
# Pandalatesta
# RomannKer
# franceEcoMag
# Hemail_79
# LaurentAlfonso
# ArnCollignon
# lesradicaux_
# 365jeuxenfamil1
# rlarvent
# rococo321
# dlbrgn
# cci_ardennes
# dominique_meda
# SophieBellon
# frlinget
# jedy00075
# fdecoster
# gyrovaguerie
# PierreCazeneuve
# EricSartori3
# jmvittori
# RE_RueilMalmais
# geholf
# atterres
# PhilippeBUERCH
# GIRcontact
# BusinessBourse
# AnneMarieJean1
# JaneOfArc6
# eelvParis10
# jamy_william
# 7Milx1
# JCEV15
# LaurePressac
# LDinclaux
# RL_Patriote
# ArnaudAbel
# GregIenco
# PatDucratin
# greenvincent
# RobyAgathe
# Nikki_Sane
# Solange__C
# Departement_971
# presseocean
# YoussefDoghmane
# JadoreMontreal
# PiNetworkFrance
# clesdusocial
# amandine_ynwa
# Maxime92160
# EcoloParis19
# lailatov
# MHAmiable
# JohnMitchell4x8
# Mikaa_H2
# FuriousKoen
# rosemarie4710
# ulyssedorioz
# IamEntry
# JM_Verchere
# laurentdejoie
# EyquemLeonard
# StanGuerini
# Mobrooo
# ManciniIsabelle
# marcgrosman75
# FindinLanguedoc
# S_Revages
# SebStanBono
# LeDL737401
# ademe_bretagne
# NicolasKlatka
# flyCSI
# pabouger
# Spike2577
# JeremieLandreau
# RaynaldBernier
# CabinetGsell
# FdeRugy
# FairPlay4Planet
# MartinFierro769
# Ecoyako_
# phenixfr
# SimpleF12656939
# ATokenInvestor
# nave_va
# BenjaminTeoule
# AdriendeVlt
# ch_lemercier
# MoukouB
# Melenchon4Ever
# CecileVignesM
# Lacjoe1
# ecoleiet
# vincent_monot
# PHD442
# GHClamart
# FabienneGrebert
# leparisien2024
# lp_materre
# DeremeAvocat
# KimKimuntu
# pascal_mulegwa
# acprdc_Officiel
# Linossier7
# meteo60
# Lamasticot__
# haricotsbleus
# RaymondBykouko
# aeros_wing
# franckcourchamp
# Victor_obrt
# laulecoeur
# anne_sicard
# lau68951920
# Stonks_Corp
# TabouleAAAAAAAH
# matgautier
# LucasPetit92
# homocommuniste
# voxjaen
# LEPETITSteph
# ChMerchadou
# LoucasPinto1
# vinzradio
# kevCi3
# fnadac
# PatrickMonin71
# ABPtwit
# Eleazar_jd
# ThomasL18174027
# Cmo351
# fred_mrs
# chateau_gontier
# matzenox
# DudesertFred
# CRECQ
# GregRoquett
# AlexisJanicot
# dm_petit
# Canope_40
# VRwatchingU
# TanShanLiMTL
# chanezherbanne
# sophiepiard
# HugCharbonneau
# Burlesque_32
# EmmanFernandes
# didjule
# VilledeChenove
# ChloeClair_namR
# Izidra_
# danlert
# VicGranier
# Ccesoir
# tcoiffeurjustes
# ChrisLavaquerie
# AnneTallineau
# SoniaBEKO
# HMassenet
# corsenetinfos
# EricKrezel
# GreenpeaceTours
# RANCHEREP
# lepenenchon

# %%
# Convertir les colonnes en type numérique
dict_acteurs_final['Tweets'] = pd.to_numeric(dict_acteurs_final['Tweets'], errors='coerce')
dict_acteurs_final['Following'] = pd.to_numeric(dict_acteurs_final['Following'], errors='coerce')
dict_acteurs_final['Followers'] = pd.to_numeric(dict_acteurs_final['Followers'], errors='coerce')
dict_acteurs_final['Likes'] = pd.to_numeric(dict_acteurs_final['Likes'], errors='coerce')

# Ajout d'une colonne score qui est la somme des métriques Likes, Followers, Following et Tweets
dict_acteurs_final['Score'] = dict_acteurs_final['Likes'] + dict_acteurs_final['Followers'] + dict_acteurs_final['Following'] + dict_acteurs_final['Tweets']
dict_acteurs_final
# Out:
#       Utilisateur_id                               Utilisateur_name  \
# 0     PaysagesIroise                   Sauvegarde Paysages d'Iroise
# 1     InfosEducation                          Education & Formation
# 2    VIENSflashmober                                 Etat d'urgence
# 3        LIBERTE1311                                           eddy
# 4           PACOLLOT                            Pierre-Alain Collot
# ..               ...                                            ...
# 495        ffunivers  Orange pressé 💉💉 BioNtech 💉 NIH/Moderna 💉#BA5
# 496          DNArchi                                        DNArchi
# 497   nathalieappere                                Nathalie Appéré
# 498   BabinetCharles                                Babinet Charles
# 499  LeBreto05734837                                      Le Breton
#
#                                            Profile_bio  Tweets  Following  \
# 0    Association Sauvegarde Paysages d'Iroise (Fini...   23200        159
# 1    Veille éducation - #Formation Professionnel - ...   26018       9145
# 2    Insurrection permanente, alternative à Punishm...    1010        126
# 3                                                        90329        114
# 4    Enseignant-chercheur - Institut Champollion - ...    1195        293
# ..                                                 ...     ...        ...
# 495  « L'ignorant affirme, le savant doute, le sage...   63277       1976
# 496  DNArchi vise à questionner la conception archi...     398        256
# 497  Maire de #Rennes. Présidente de @metropolerennes.    7955       1882
# 498  Responsable #Reconquete #circo4904 ;\nCandidat...    7800        128
# 499                                                      31423       1482
#
#      Followers  Likes   Score
# 0          479  22382   46220
# 1         8520     16   43699
# 2           19    111    1266
# 3          244  19706  110393
# 4          243    897    2628
# ..         ...    ...     ...
# 495        750   9765   75768
# 496        221    127    1002
# 497      23855   3083   36775
# 498        315   2879   11122
# 499       1288  17058   51251
#
# [500 rows x 8 columns]

# %%
import csv

dict_acteurs_final.to_csv(
    'PPD_ALL_Scrapping_acteurs.csv',
    sep=';',
    index=False,
    encoding='utf-8-sig',
    #quoting=csv.QUOTE_NONE,
    #escapechar='\\'
)

# %%
dict_acteurs_final.to_excel(r'PPD_ALL_Scrapping_acteurs.xlsx', index=False)
